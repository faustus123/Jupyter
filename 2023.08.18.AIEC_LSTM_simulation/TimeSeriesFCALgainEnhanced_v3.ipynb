# %% [markdown]
# # FCAL Simulation $\alpha$ fitting with LSTM Model
#
#
# This is a copy of the TimeSeriesFCALgainEnhanced.ipynb notebook, but using the fcal_DLv2.csv file as input. That file was generated by a run of the GenerateDataset.ipynb notebook. It differes from Mike's data set primarily in that it uses a sin^2 function instead of a sawtooth function for $\alpha$
# <hr>
#
# This is mostly a copy of the TimeSeriesFCALgain.ipynb notebook except it uses the mean of all "A" values at each time step as an estimate of the $\alpha$ value which is included as an extra input. In other words, the model takes 51 inputs instead of 50 with the 51st just being the average of the other 50.
#
# Note that the estimated $\alpha$ is used as both an input feature to the LSTM model (calculated for each time step), but the value at the current time step is added to the LSTM output. This forces the actual LSTM layers to predict the _residual_ of $\alpha$ which gives a more accurate solution.
#
# <hr>
#
# <s>This notebook uses the FCAL simulation data Mike produced with a uniform sawtooth $\alpha$.</s>
#
# This fits an LSTM model using the 50 "A" values as inputs with a 200 time step history to predict the value of $\alpha$ of the current time step.
#
# This is based on the keras Timeseries example for weather forecasting found here:
# https://keras.io/examples/timeseries/timeseries_weather_forecasting
#
#
# This first cell just reads the data, renames the "b*" columns to "A*", and calculates the true $\alpha$, adding it to the dataframe.

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

tf.keras.backend.set_floatx('float64')

version = 3
filename = f'fcal_DLv{version}.csv'

df = pd.read_csv(filename)

# Rename columns from "bX" to "AX" to better align with what we say vocally
name_map = {}
for i in range(1,51):
    name_map['b'+str(i)] = 'A'+str(i)
df = df.rename(columns=name_map)

# Calculate alpha (should work for any pair)
#df['alpha'] = df['A23']/df['g23']

df['Aalpha_est'] = df.filter(like="A").mean(axis=1)

df.plot(y=["A17", "g17", "alpha", "w17"], kind="line", grid=True, ylim=(0.85, 1.06),figsize=(10,3))

print("Cell completed at:", datetime.datetime.now())
# Out:
# 2023-08-28 15:16:33.850093: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-28 15:16:34.001557: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-28 15:16:34.003525: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-28 15:16:36.482867: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cell completed at: 2023-08-28 15:16:38.756301

# %% [markdown]
# ## Prepare training and validation sets
#
# This will split the data into training and validation sets. Note that the normalization function (copied from the original keras example) is not used since it seemed to result in much worse model fits. This is not such an issue for this data set since the values are already in a small range around 1.

# %%
split_fraction = 0.70
train_split = int(split_fraction * int(df.shape[0]))
step = 1

past = 200   # number of timesteps in the past to use for predicting value(s) for current timestep
future = 0   # number of timesteps in the future to predict value for
learning_rate = 0.002
batch_size = 64
epochs_model1 = 5000
epochs_model2 = 200

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std


# Create nomalized training and validation sets
# df_norm  = normalize(df, train_split)  # This gives really bad model fits! Do not use!
df_norm  = df
df_train = df_norm[:train_split-1]
df_valid = df_norm[train_split:]
df_train_labels = df[:train_split-1]  # unormalized!
df_valid_labels = df[train_split:]    # unormalized!

# Chop off ends so we have a full set of past elements and corresponding future
x_train = df_train.filter(like="A").values
y_train = df_train_labels.filter(items=["alpha"])[past+future-1:].values
x_valid = df_valid.filter(like="A").values
y_valid = df_valid_labels.filter(items=["alpha"])[past+future-1:].values
print("x_train shape: "+str(x_train.shape) + "   y_train shape: "+str(y_train.shape))
print("x_valid shape: "+str(x_valid.shape) + "   y_valid shape: "+str(y_valid.shape))
# Out:
# x_train shape: (2099, 51)   y_train shape: (1900, 1)
# x_valid shape: (900, 51)   y_valid shape: (701, 1)

# %% [markdown]
# ### Create Timeseries datasets
#
# This creates datasets in a form that can be easily used for training. Note that we use overlapping points. E.g. time steps 0-199 are used to predict $\alpha_{199}$, time steps 1-200 are used to predict $\alpha_{200}$, etc...
#
# The labels ("y"s defined in the cell above) start with the first predicted value. E.g. y_train[0] = $\alpha_{199}$, y_train[1] = $\alpha_{200}$, ...

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_train.take(1): train_inputs, train_targets = batch
print("  Training: Input shape:", train_inputs.numpy().shape, " Target shape:" , train_targets.numpy().shape)

dataset_valid = keras.preprocessing.timeseries_dataset_from_array(
    x_valid,
    y_valid,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_valid.take(1): valid_inputs, valid_targets = batch
print("Validation: Input shape:", valid_inputs.numpy().shape, " Target shape:" , valid_targets.numpy().shape)
# Out:
# 2023-08-28 15:16:39.390574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_28' with dtype int32 and shape [1900]
# 	 [[{{node Placeholder/_28}}]]
# 2023-08-28 15:16:39.391579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_28' with dtype int32 and shape [1900]
# 	 [[{{node Placeholder/_28}}]]
#   Training: Input shape: (64, 200, 51)  Target shape: (64, 1)
# Validation: Input shape: (64, 200, 51)  Target shape: (64, 1)
# 2023-08-28 15:16:39.664847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_13' with dtype int32
# 	 [[{{node Placeholder/_13}}]]
# 2023-08-28 15:16:39.665873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_14' with dtype int32
# 	 [[{{node Placeholder/_14}}]]

# %% [markdown]
# ## Create Model 1
#
# This creates a simple model that uses just the estimated $\alpha$ and one Dense layer with 2 trainable parameters. It is fast and gives a pretty good result (<1% error). The layers and weights of this will be locked, but then used to create a second model later.

# %%
inputs = keras.layers.Input(shape=(train_inputs.shape[1], train_inputs.shape[2]))

# Estimated alpha for current time step
alpha_est_out = keras.layers.Lambda(lambda x: x[:, -1, -1])(inputs)
alpha_est_out = keras.layers.Reshape((1,))(alpha_est_out)
outputs       = keras.layers.Dense(1, activation="linear")(alpha_est_out)

model1 = keras.Model(inputs=inputs, outputs=outputs, name="model1")
model1.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model1.summary()
# Out:
# Model: "model1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 51)]         0
#
#  lambda (Lambda)             (None,)                   0
#
#  reshape (Reshape)           (None, 1)                 0
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit Model 1
#
# Use early stopping and save the best model to a _.h5_ file.

# %%
path_checkpoint = f"model1_checkpointv{version}.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=0,
    save_weights_only=True,
    save_best_only=True,
)

history1 = model1.fit(
    dataset_train,
    epochs=epochs_model1,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)

print("Cell completed at:", datetime.datetime.now())
# Out:
# 2023-08-28 15:16:39.987021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_20' with dtype double and shape [1900,1]
# 	 [[{{node Placeholder/_20}}]]
# 2023-08-28 15:16:39.988007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_28' with dtype int32 and shape [1900]
# 	 [[{{node Placeholder/_28}}]]
# Epoch 1/5000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.2724
# 2023-08-28 15:16:41.345663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_28' with dtype int32 and shape [701]
# 	 [[{{node Placeholder/_28}}]]
# 2023-08-28 15:16:41.347009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype int32 and shape [701]
# 	 [[{{node Placeholder/_8}}]]
# 30/30 [==============================] - 2s 28ms/step - loss: 0.2652 - val_loss: 0.2053
# Epoch 2/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1617 - val_loss: 0.1201
# Epoch 3/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0917 - val_loss: 0.0654
# Epoch 4/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0484 - val_loss: 0.0330
# Epoch 5/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0235 - val_loss: 0.0153
# Epoch 6/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0105 - val_loss: 0.0065
# Epoch 7/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 8/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 8.8817e-04
# Epoch 9/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.4777e-04 - val_loss: 2.8533e-04
# Epoch 10/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6961e-04 - val_loss: 8.3248e-05
# Epoch 11/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.7692e-05 - val_loss: 2.2013e-05
# Epoch 12/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.2151e-05 - val_loss: 5.2610e-06
# Epoch 13/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 2.7971e-06 - val_loss: 1.1324e-06
# Epoch 14/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.7947e-07 - val_loss: 2.1853e-07
# Epoch 15/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 1.0751e-07 - val_loss: 3.7585e-08
# Epoch 16/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7752e-08 - val_loss: 5.7184e-09
# Epoch 17/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 2.5880e-09 - val_loss: 7.6223e-10
# Epoch 18/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 3.2969e-10 - val_loss: 8.7886e-11
# Epoch 19/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 3.6202e-11 - val_loss: 8.6138e-12
# Epoch 20/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 3.3622e-12 - val_loss: 6.9993e-13
# Epoch 21/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 2.5694e-13 - val_loss: 4.5359e-14
# Epoch 22/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 1.5469e-14 - val_loss: 2.1913e-15
# Epoch 23/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 6.7843e-16 - val_loss: 6.8357e-17
# Epoch 24/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 1.8187e-17 - val_loss: 8.6660e-19
# Epoch 25/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 1.6102e-19 - val_loss: 1.5179e-21
# Epoch 26/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.0165e-21 - val_loss: 2.7755e-21
# Epoch 27/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 1.1616e-21 - val_loss: 2.1317e-22
# Epoch 28/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 6.3229e-23 - val_loss: 4.0882e-24
# Epoch 29/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 7.9641e-25 - val_loss: 4.1465e-27
# Epoch 30/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 1.5626e-26 - val_loss: 1.0707e-26
# Epoch 31/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.0838e-27 - val_loss: 5.1800e-28
# Epoch 32/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 1.2314e-28 - val_loss: 7.8886e-31
# Epoch 33/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 3.5779e-31 - val_loss: 4.4373e-31
# Epoch 34/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 35/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 36/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 37/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 38/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 39/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 40/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 41/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 42/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 43/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 44/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 45/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 46/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 47/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 48/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 49/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 50/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 51/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 52/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 53/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 54/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 55/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 56/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 57/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 58/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 59/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 60/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 61/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 62/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 63/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 64/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 65/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 66/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 67/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 68/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 69/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 70/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 71/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 72/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 73/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 74/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.4373e-31 - val_loss: 4.4373e-31
# Epoch 75/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.7195e-31 - val_loss: 1.9722e-31
# Epoch 76/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 77/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 78/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 79/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 80/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 81/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 82/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 83/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 84/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 85/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 86/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 87/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 88/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 89/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 90/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 91/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 92/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 93/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 94/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 95/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 96/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 97/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 98/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 99/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9722e-31 - val_loss: 1.9722e-31
# Epoch 100/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 1.0411e-31 - val_loss: 4.9304e-32
# Epoch 101/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 102/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 103/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 104/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 105/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 106/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 107/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 108/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 109/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 110/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 111/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 112/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 113/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 114/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 115/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 116/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 117/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 118/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 119/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 120/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 121/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 122/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 123/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 124/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 125/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 126/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 127/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 128/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 129/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 130/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 131/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 132/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 133/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 134/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 135/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 136/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 137/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 138/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 139/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 140/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 141/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 142/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 143/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 144/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.9304e-32 - val_loss: 4.9304e-32
# Epoch 145/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 8.3038e-33 - val_loss: 0.0000e+00
# Epoch 146/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 147/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 148/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 149/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 150/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 151/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 152/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 153/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 154/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 155/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 156/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 157/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 158/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 159/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 160/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 161/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 162/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 163/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 164/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 165/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 166/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 167/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 168/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 169/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 170/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 171/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 172/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 173/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 174/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 175/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 176/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 177/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 178/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 179/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 180/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 181/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 182/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 183/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 184/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 185/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 186/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 187/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 188/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 189/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 190/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 191/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 192/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 193/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 194/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 195/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Cell completed at: 2023-08-28 15:18:51.429784

# %% [markdown]
# ### Loss Function Model 1
#
# n.b. This is plotted on a log scale

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.yscale("log")
    plt.legend()
    plt.show()


visualize_loss(history1, "Training and Validation Loss")

# %% [markdown]
# ## Results Model 1
#
# The following cell performs inference on the entire dataset (training and validation). The results are stored in the original dataframe as column "alpha_model1".

# %%
# Create overlapping windows of data
x_all = df_norm.filter(like="A").values
num_windows = x_all.shape[0] - past +1
windows = np.lib.stride_tricks.sliding_window_view(x_all, (past, x_all.shape[1]))

df['alpha_model1'] = np.nan

# Predict using batches and update df
batch_size_ = 32
for i in range(0, num_windows, batch_size_):
    batch_windows = windows[i:i+batch_size_]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model1.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model1'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")

print("\rprocessed: {}/{}".format(num_windows, num_windows), end="")
# Out:
# processed: 2801/2801

# %% [markdown]
# # $\alpha$ Model 1 vs Truth
#
# The top plot below shows the true $\alpha$ and the one predicted by model 1. Since the model requires 200 past timesteps, its predictions are only available for timestep 200 and later.
#
# The bottom plot shows the error (residual) bewtween $\alpha$ and the model 1 prediction.

# %%
df.plot(y=["alpha_model1", "alpha"], kind="line", grid=True, figsize=(10,3))

df["alpha_res1"] = df["alpha_model1"] - df["alpha"]
df.plot(y=["alpha_res1"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# ## Create Model 2
#
# This creates an LSTM model that uses just the model 1 output of a corrected estimated $\alpha$ as input. The LSTM model is then trained to correct the residual. The layers of model 1 are reused here, but the two trainable parameters are locked so as not no be updated by this model's training, forcing the additional layers of this model to fit to the residual.

# %%
# Lock the parameters in model 1
outputs.trainable = False

# Residual for corrected alpha
lstm_out = keras.layers.LSTM(200, activation="tanh", recurrent_activation="tanh", kernel_initializer='zeros')(inputs)
residual_out = keras.layers.Dense(1, activation="tanh", kernel_initializer='zeros')(lstm_out)

# The residual should be a small number relative to 1. Scale the value down here to put it in a reasonable range
residual_out = keras.layers.Lambda(lambda x: x * 0.10)(residual_out)

# Add model 1 and residual to make outputs for model 2
outputs2 = keras.layers.Add()([outputs, residual_out])


model2 = keras.Model(inputs=inputs, outputs=outputs2, name="model2")
model2.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model2.summary()

import datetime
# Out:
# Model: "model2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 51)]    0           []
#
#  lambda (Lambda)                (None,)              0           ['input_1[0][0]']
#
#  lstm (LSTM)                    (None, 200)          201600      ['input_1[0][0]']
#
#  reshape (Reshape)              (None, 1)            0           ['lambda[0][0]']
#
#  dense_1 (Dense)                (None, 1)            201         ['lstm[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['reshape[0][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['dense_1[0][0]']
#
#  add (Add)                      (None, 1)            0           ['dense[0][0]',
#                                                                   'lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 201,803
# Trainable params: 201,803
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Fit Model 2
#
# Use early stopping and save the best model to a _.h5_ file.

# %%
path_checkpoint = f"model2_checkpointv{version}.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history2 = model2.fit(
    dataset_train,
    epochs=epochs_model1,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)

print("Cell completed at:", datetime.datetime.now())
# Out:
# Epoch 1/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 1: val_loss improved from inf to 0.00000, saving model to model2_checkpointv3.h5
# 30/30 [==============================] - 25s 760ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 2/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 2: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 758ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 3: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 763ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 4/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 4: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 758ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 5: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 767ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 6/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 6: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 830ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 7: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 765ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 8/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 8: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 752ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 9: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 759ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 10/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 10: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 755ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 11: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 741ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 12/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 12: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 746ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 13: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 734ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 14/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 14: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 886ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 15: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 814ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 16/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 16: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 866ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 17: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 816ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 18/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 18: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 831ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 19: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 802ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 20/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 20: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 825ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 21: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 819ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 22/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 22: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 789ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 23: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 804ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 24/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 24: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 832ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 25: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 802ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 26/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 26: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 819ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 27: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 825ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 28/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 28: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 805ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 29: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 884ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 30/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 30: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 831ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 31: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 842ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 32/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 32: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 735ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 33: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 849ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 34/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 34: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 821ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 35: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 883ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 36/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 36: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 870ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 37: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 864ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 38/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 38: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 858ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 39: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 858ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 40/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 40: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 805ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 41: val_loss did not improve from 0.00000
# 30/30 [==============================] - 27s 905ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 42/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 42: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 828ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 43: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 835ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 44/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 44: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 878ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 45: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 868ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 46/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 46: val_loss did not improve from 0.00000
# 30/30 [==============================] - 28s 924ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 47: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 880ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 48/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 48: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 884ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 49/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 49: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 833ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 50/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 50: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 796ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 51/5000
# 30/30 [==============================] - ETA: 0s - loss: 0.0000e+00
# Epoch 51: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 871ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Cell completed at: 2023-08-28 15:41:35.809353

# %% [markdown]
# ### Loss Function Model 2
#
# n.b. This is plotted on a log scale

# %%
visualize_loss(history2, "Training and Validation Loss")
# Out:
# /tmp/ipykernel_71106/2976933182.py:11: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")

# %% [markdown]
# ## Results Model 2
#
# The following cell performs inference on the entire dataset (training and validation). The results are stored in the original dataframe as column "alpha_model2".

# %%
df['alpha_model2'] = np.nan

# Predict using batches and update df
batch_size_ = 32
for i in range(0, num_windows, batch_size_):
    batch_windows = windows[i:i+batch_size_]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model2.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model2'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")

print("\rprocessed: {}/{}".format(num_windows, num_windows), end="")
# Out:
# processed: 2801/2801

# %% [markdown]
# # $\alpha$ Model 2 vs Truth
#
# The top plot below shows the true $\alpha$ and the one predicted by model 2. Since the model requires 200 past timesteps, its predictions are only available for timestep 200 and later.
#
# The bottom plot shows the error (residual) bewtween $\alpha$ and the model 2 prediction.

# %%
df.plot(y=["alpha_model1", "alpha", "alpha_model2"], kind="line", grid=True, figsize=(10,3))

df["alpha_res2"] = df["alpha_model2"] - df["alpha"]
df.plot(y=["alpha_res1", "alpha_res2"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# # Basement
# <hr>

# %% [markdown]
# ### Example predictions
#
# Plot a few examples showing the $\alpha$ truth history and the model prediction. This is also carried over from the keras weather example. The red "X" is just the last point in the truth history since here, we are not trying to predict the future, only use the past to predict the present.
#
# n.b. Unlike the original example for the weather which included Temperature in the features and was used to predict Temperature in the future, this problem does not directly measure $\alpha$. Thus these blue points are useful to guide the human eye, but are not values the model sees.
#
# The first 3 plots are from the validation set while the second three are from the training set.

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future_ = delta
    else:
        future_ = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future_, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend(loc="upper left")
    plt.xlim([time_steps[0], (future_ + 5) * 2])
    plt.ylim([0.90, 1.10])
    plt.xlabel("Time-Step")
    plt.show()
    return

# This has the alpha history with last point being the same as the label
alpha_valid = df_valid_labels.filter(items=["alpha"])[:-(past+future)].values
alpha_train = df_train_labels.filter(items=["alpha"])[:-(past+future)].values

 
# Validation examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_valid[start:start+past], 0)
    y_history = alpha_valid[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model2.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from Validation Set")

# Training examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_train[start:start+past], 0)
    y_history = alpha_train[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model2.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from training Set")
# Out:
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 71ms/step
