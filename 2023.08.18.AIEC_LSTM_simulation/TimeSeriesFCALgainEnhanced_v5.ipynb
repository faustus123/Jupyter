# %% [markdown]
# # FCAL Simulation $\alpha$ fitting with LSTM Model
#
#
# This is a copy of the TimeSeriesFCALgainEnhanced.ipynb notebook, but using the fcal_DLv2.csv file as input. That file was generated by a run of the GenerateDataset.ipynb notebook. It differes from Mike's data set primarily in that it uses a sin^2 function instead of a sawtooth function for $\alpha$
# <hr>
#
# This is mostly a copy of the TimeSeriesFCALgain.ipynb notebook except it uses the mean of all "A" values at each time step as an estimate of the $\alpha$ value which is included as an extra input. In other words, the model takes 51 inputs instead of 50 with the 51st just being the average of the other 50.
#
# Note that the estimated $\alpha$ is used as both an input feature to the LSTM model (calculated for each time step), but the value at the current time step is added to the LSTM output. This forces the actual LSTM layers to predict the _residual_ of $\alpha$ which gives a more accurate solution.
#
# <hr>
#
# <s>This notebook uses the FCAL simulation data Mike produced with a uniform sawtooth $\alpha$.</s>
#
# This fits an LSTM model using the 50 "A" values as inputs with a 200 time step history to predict the value of $\alpha$ of the current time step.
#
# This is based on the keras Timeseries example for weather forecasting found here:
# https://keras.io/examples/timeseries/timeseries_weather_forecasting
#
#
# This first cell just reads the data, renames the "b*" columns to "A*", and calculates the true $\alpha$, adding it to the dataframe.

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

tf.keras.backend.set_floatx('float64')

version = 5
filename = f'fcal_DLv{version}.csv'

df = pd.read_csv(filename)

# Rename columns from "bX" to "AX" to better align with what we say vocally
name_map = {}
for i in range(1,51):
    name_map['b'+str(i)] = 'A'+str(i)
df = df.rename(columns=name_map)

# Calculate alpha (should work for any pair)
#df['alpha'] = df['A23']/df['g23']

df['Aalpha_est'] = df.filter(like="A").mean(axis=1)

df.plot(y=["A17", "g17", "alpha", "w17"], kind="line", grid=True, ylim=(0.85, 1.06),figsize=(10,3))

print("Cell completed at:", datetime.datetime.now())
# Out:
# 2023-08-28 15:16:37.202105: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-28 15:16:37.310852: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-28 15:16:37.314468: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-28 15:16:38.830552: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cell completed at: 2023-08-28 15:16:41.478960

# %% [markdown]
# ## Prepare training and validation sets
#
# This will split the data into training and validation sets. Note that the normalization function (copied from the original keras example) is not used since it seemed to result in much worse model fits. This is not such an issue for this data set since the values are already in a small range around 1.

# %%
split_fraction = 0.70
train_split = int(split_fraction * int(df.shape[0]))
step = 1

past = 200   # number of timesteps in the past to use for predicting value(s) for current timestep
future = 0   # number of timesteps in the future to predict value for
learning_rate = 0.002
batch_size = 64
epochs_model1 = 5000
epochs_model2 = 200

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std


# Create nomalized training and validation sets
# df_norm  = normalize(df, train_split)  # This gives really bad model fits! Do not use!
df_norm  = df
df_train = df_norm[:train_split-1]
df_valid = df_norm[train_split:]
df_train_labels = df[:train_split-1]  # unormalized!
df_valid_labels = df[train_split:]    # unormalized!

# Chop off ends so we have a full set of past elements and corresponding future
x_train = df_train.filter(like="A").values
y_train = df_train_labels.filter(items=["alpha"])[past+future-1:].values
x_valid = df_valid.filter(like="A").values
y_valid = df_valid_labels.filter(items=["alpha"])[past+future-1:].values
print("x_train shape: "+str(x_train.shape) + "   y_train shape: "+str(y_train.shape))
print("x_valid shape: "+str(x_valid.shape) + "   y_valid shape: "+str(y_valid.shape))
# Out:
# x_train shape: (2099, 51)   y_train shape: (1900, 1)
# x_valid shape: (900, 51)   y_valid shape: (701, 1)

# %% [markdown]
# ### Create Timeseries datasets
#
# This creates datasets in a form that can be easily used for training. Note that we use overlapping points. E.g. time steps 0-199 are used to predict $\alpha_{199}$, time steps 1-200 are used to predict $\alpha_{200}$, etc...
#
# The labels ("y"s defined in the cell above) start with the first predicted value. E.g. y_train[0] = $\alpha_{199}$, y_train[1] = $\alpha_{200}$, ...

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_train.take(1): train_inputs, train_targets = batch
print("  Training: Input shape:", train_inputs.numpy().shape, " Target shape:" , train_targets.numpy().shape)

dataset_valid = keras.preprocessing.timeseries_dataset_from_array(
    x_valid,
    y_valid,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_valid.take(1): valid_inputs, valid_targets = batch
print("Validation: Input shape:", valid_inputs.numpy().shape, " Target shape:" , valid_targets.numpy().shape)
# Out:
# 2023-08-28 15:16:42.731815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_20' with dtype double and shape [1900,1]
# 	 [[{{node Placeholder/_20}}]]
# 2023-08-28 15:16:42.732743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_20' with dtype double and shape [1900,1]
# 	 [[{{node Placeholder/_20}}]]
#   Training: Input shape: (64, 200, 51)  Target shape: (64, 1)
# Validation: Input shape: (64, 200, 51)  Target shape: (64, 1)
# 2023-08-28 15:16:43.077599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype int32 and shape [701]
# 	 [[{{node Placeholder/_8}}]]
# 2023-08-28 15:16:43.078331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_20' with dtype double and shape [701,1]
# 	 [[{{node Placeholder/_20}}]]

# %% [markdown]
# ## Create Model 1
#
# This creates a simple model that uses just the estimated $\alpha$ and one Dense layer with 2 trainable parameters. It is fast and gives a pretty good result (<1% error). The layers and weights of this will be locked, but then used to create a second model later.

# %%
inputs = keras.layers.Input(shape=(train_inputs.shape[1], train_inputs.shape[2]))

# Estimated alpha for current time step
alpha_est_out = keras.layers.Lambda(lambda x: x[:, -1, -1])(inputs)
alpha_est_out = keras.layers.Reshape((1,))(alpha_est_out)
outputs       = keras.layers.Dense(1, activation="linear")(alpha_est_out)

model1 = keras.Model(inputs=inputs, outputs=outputs, name="model1")
model1.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model1.summary()
# Out:
# Model: "model1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 51)]         0
#
#  lambda (Lambda)             (None,)                   0
#
#  reshape (Reshape)           (None, 1)                 0
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit Model 1
#
# Use early stopping and save the best model to a _.h5_ file.

# %%
path_checkpoint = f"model1_checkpointv{version}.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=0,
    save_weights_only=True,
    save_best_only=True,
)

history1 = model1.fit(
    dataset_train,
    epochs=epochs_model1,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)

print("Cell completed at:", datetime.datetime.now())
# Out:
# Epoch 1/5000
# 2023-08-28 15:16:43.583627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_28' with dtype int32 and shape [1900]
# 	 [[{{node Placeholder/_28}}]]
# 2023-08-28 15:16:43.584749: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_28' with dtype int32 and shape [1900]
# 	 [[{{node Placeholder/_28}}]]
# 28/30 [===========================>..] - ETA: 0s - loss: 1.7134
# 2023-08-28 15:16:45.134868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_20' with dtype double and shape [701,1]
# 	 [[{{node Placeholder/_20}}]]
# 2023-08-28 15:16:45.135744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [900,51]
# 	 [[{{node Placeholder/_0}}]]
# 30/30 [==============================] - 2s 30ms/step - loss: 1.7038 - val_loss: 1.5460
# Epoch 2/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.4120 - val_loss: 1.2741
# Epoch 3/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1585 - val_loss: 1.0400
# Epoch 4/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.9413 - val_loss: 0.8406
# Epoch 5/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 0.7572 - val_loss: 0.6723
# Epoch 6/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.6026 - val_loss: 0.5320
# Epoch 7/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 0.4743 - val_loss: 0.4161
# Epoch 8/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3690 - val_loss: 0.3217
# Epoch 9/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2837 - val_loss: 0.2457
# Epoch 10/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2154 - val_loss: 0.1852
# Epoch 11/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1614 - val_loss: 0.1379
# Epoch 12/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1194 - val_loss: 0.1013
# Epoch 13/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0872 - val_loss: 0.0734
# Epoch 14/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0628 - val_loss: 0.0526
# Epoch 15/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0447 - val_loss: 0.0371
# Epoch 16/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0314 - val_loss: 0.0259
# Epoch 17/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0218 - val_loss: 0.0179
# Epoch 18/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0149 - val_loss: 0.0122
# Epoch 19/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0102 - val_loss: 0.0083
# Epoch 20/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 21/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 22/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 23/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 24/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 25/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 26/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 9.4270e-04 - val_loss: 8.5803e-04
# Epoch 27/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 7.9245e-04 - val_loss: 7.4237e-04
# Epoch 28/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 7.0215e-04 - val_loss: 6.7332e-04
# Epoch 29/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 6.4886e-04 - val_loss: 6.3279e-04
# Epoch 30/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 6.1799e-04 - val_loss: 6.0939e-04
# Epoch 31/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 6.0045e-04 - val_loss: 5.9612e-04
# Epoch 32/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.9067e-04 - val_loss: 5.8870e-04
# Epoch 33/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.8533e-04 - val_loss: 5.8462e-04
# Epoch 34/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.8247e-04 - val_loss: 5.8239e-04
# Epoch 35/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.8097e-04 - val_loss: 5.8118e-04
# Epoch 36/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.8018e-04 - val_loss: 5.8051e-04
# Epoch 37/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.7976e-04 - val_loss: 5.8012e-04
# Epoch 38/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7952e-04 - val_loss: 5.7987e-04
# Epoch 39/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.7937e-04 - val_loss: 5.7970e-04
# Epoch 40/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.7925e-04 - val_loss: 5.7955e-04
# Epoch 41/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.7914e-04 - val_loss: 5.7942e-04
# Epoch 42/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.7904e-04 - val_loss: 5.7929e-04
# Epoch 43/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.7893e-04 - val_loss: 5.7916e-04
# Epoch 44/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.7881e-04 - val_loss: 5.7903e-04
# Epoch 45/5000
# 30/30 [==============================] - 1s 16ms/step - loss: 5.7869e-04 - val_loss: 5.7890e-04
# Epoch 46/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.7857e-04 - val_loss: 5.7876e-04
# Epoch 47/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 5.7844e-04 - val_loss: 5.7862e-04
# Epoch 48/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.7831e-04 - val_loss: 5.7848e-04
# Epoch 49/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.7817e-04 - val_loss: 5.7833e-04
# Epoch 50/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.7804e-04 - val_loss: 5.7818e-04
# Epoch 51/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.7789e-04 - val_loss: 5.7803e-04
# Epoch 52/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.7775e-04 - val_loss: 5.7788e-04
# Epoch 53/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.7760e-04 - val_loss: 5.7772e-04
# Epoch 54/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.7745e-04 - val_loss: 5.7756e-04
# Epoch 55/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.7730e-04 - val_loss: 5.7739e-04
# Epoch 56/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7714e-04 - val_loss: 5.7723e-04
# Epoch 57/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.7698e-04 - val_loss: 5.7706e-04
# Epoch 58/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.7682e-04 - val_loss: 5.7689e-04
# Epoch 59/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7666e-04 - val_loss: 5.7671e-04
# Epoch 60/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7649e-04 - val_loss: 5.7653e-04
# Epoch 61/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7632e-04 - val_loss: 5.7635e-04
# Epoch 62/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.7614e-04 - val_loss: 5.7617e-04
# Epoch 63/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.7597e-04 - val_loss: 5.7598e-04
# Epoch 64/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.7578e-04 - val_loss: 5.7579e-04
# Epoch 65/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.7560e-04 - val_loss: 5.7559e-04
# Epoch 66/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.7541e-04 - val_loss: 5.7539e-04
# Epoch 67/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7522e-04 - val_loss: 5.7519e-04
# Epoch 68/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7503e-04 - val_loss: 5.7499e-04
# Epoch 69/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.7483e-04 - val_loss: 5.7478e-04
# Epoch 70/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.7463e-04 - val_loss: 5.7457e-04
# Epoch 71/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.7443e-04 - val_loss: 5.7435e-04
# Epoch 72/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 5.7422e-04 - val_loss: 5.7413e-04
# Epoch 73/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.7401e-04 - val_loss: 5.7391e-04
# Epoch 74/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.7380e-04 - val_loss: 5.7368e-04
# Epoch 75/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.7358e-04 - val_loss: 5.7345e-04
# Epoch 76/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.7336e-04 - val_loss: 5.7322e-04
# Epoch 77/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 5.7314e-04 - val_loss: 5.7298e-04
# Epoch 78/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 5.7291e-04 - val_loss: 5.7274e-04
# Epoch 79/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 5.7268e-04 - val_loss: 5.7250e-04
# Epoch 80/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.7244e-04 - val_loss: 5.7225e-04
# Epoch 81/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.7220e-04 - val_loss: 5.7199e-04
# Epoch 82/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.7196e-04 - val_loss: 5.7174e-04
# Epoch 83/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 5.7171e-04 - val_loss: 5.7147e-04
# Epoch 84/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.7146e-04 - val_loss: 5.7121e-04
# Epoch 85/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 5.7120e-04 - val_loss: 5.7094e-04
# Epoch 86/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 5.7094e-04 - val_loss: 5.7067e-04
# Epoch 87/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.7068e-04 - val_loss: 5.7039e-04
# Epoch 88/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.7041e-04 - val_loss: 5.7010e-04
# Epoch 89/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.7014e-04 - val_loss: 5.6982e-04
# Epoch 90/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.6986e-04 - val_loss: 5.6953e-04
# Epoch 91/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.6958e-04 - val_loss: 5.6923e-04
# Epoch 92/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.6930e-04 - val_loss: 5.6893e-04
# Epoch 93/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.6901e-04 - val_loss: 5.6863e-04
# Epoch 94/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.6871e-04 - val_loss: 5.6832e-04
# Epoch 95/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.6842e-04 - val_loss: 5.6800e-04
# Epoch 96/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.6811e-04 - val_loss: 5.6768e-04
# Epoch 97/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.6781e-04 - val_loss: 5.6736e-04
# Epoch 98/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 5.6749e-04 - val_loss: 5.6703e-04
# Epoch 99/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.6718e-04 - val_loss: 5.6670e-04
# Epoch 100/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.6685e-04 - val_loss: 5.6636e-04
# Epoch 101/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.6653e-04 - val_loss: 5.6602e-04
# Epoch 102/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 5.6620e-04 - val_loss: 5.6567e-04
# Epoch 103/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.6586e-04 - val_loss: 5.6531e-04
# Epoch 104/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.6552e-04 - val_loss: 5.6495e-04
# Epoch 105/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.6517e-04 - val_loss: 5.6459e-04
# Epoch 106/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.6482e-04 - val_loss: 5.6422e-04
# Epoch 107/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.6446e-04 - val_loss: 5.6385e-04
# Epoch 108/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.6410e-04 - val_loss: 5.6346e-04
# Epoch 109/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.6374e-04 - val_loss: 5.6308e-04
# Epoch 110/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.6336e-04 - val_loss: 5.6269e-04
# Epoch 111/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.6298e-04 - val_loss: 5.6229e-04
# Epoch 112/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.6260e-04 - val_loss: 5.6189e-04
# Epoch 113/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.6221e-04 - val_loss: 5.6148e-04
# Epoch 114/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.6182e-04 - val_loss: 5.6106e-04
# Epoch 115/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.6142e-04 - val_loss: 5.6064e-04
# Epoch 116/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 5.6101e-04 - val_loss: 5.6022e-04
# Epoch 117/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.6060e-04 - val_loss: 5.5978e-04
# Epoch 118/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.6018e-04 - val_loss: 5.5934e-04
# Epoch 119/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.5976e-04 - val_loss: 5.5890e-04
# Epoch 120/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.5933e-04 - val_loss: 5.5845e-04
# Epoch 121/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.5889e-04 - val_loss: 5.5799e-04
# Epoch 122/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.5845e-04 - val_loss: 5.5753e-04
# Epoch 123/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.5800e-04 - val_loss: 5.5706e-04
# Epoch 124/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.5754e-04 - val_loss: 5.5658e-04
# Epoch 125/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.5708e-04 - val_loss: 5.5610e-04
# Epoch 126/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.5661e-04 - val_loss: 5.5561e-04
# Epoch 127/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.5614e-04 - val_loss: 5.5511e-04
# Epoch 128/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.5566e-04 - val_loss: 5.5461e-04
# Epoch 129/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.5517e-04 - val_loss: 5.5409e-04
# Epoch 130/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.5468e-04 - val_loss: 5.5358e-04
# Epoch 131/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.5418e-04 - val_loss: 5.5305e-04
# Epoch 132/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.5367e-04 - val_loss: 5.5252e-04
# Epoch 133/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.5316e-04 - val_loss: 5.5198e-04
# Epoch 134/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.5263e-04 - val_loss: 5.5144e-04
# Epoch 135/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.5211e-04 - val_loss: 5.5088e-04
# Epoch 136/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.5157e-04 - val_loss: 5.5032e-04
# Epoch 137/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.5103e-04 - val_loss: 5.4976e-04
# Epoch 138/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 5.5048e-04 - val_loss: 5.4918e-04
# Epoch 139/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.4992e-04 - val_loss: 5.4860e-04
# Epoch 140/5000
# 30/30 [==============================] - 0s 17ms/step - loss: 5.4936e-04 - val_loss: 5.4801e-04
# Epoch 141/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 5.4878e-04 - val_loss: 5.4741e-04
# Epoch 142/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.4820e-04 - val_loss: 5.4680e-04
# Epoch 143/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.4762e-04 - val_loss: 5.4619e-04
# Epoch 144/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 5.4702e-04 - val_loss: 5.4557e-04
# Epoch 145/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 5.4642e-04 - val_loss: 5.4494e-04
# Epoch 146/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.4581e-04 - val_loss: 5.4430e-04
# Epoch 147/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.4519e-04 - val_loss: 5.4365e-04
# Epoch 148/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.4456e-04 - val_loss: 5.4300e-04
# Epoch 149/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 5.4393e-04 - val_loss: 5.4234e-04
# Epoch 150/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.4329e-04 - val_loss: 5.4167e-04
# Epoch 151/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.4264e-04 - val_loss: 5.4099e-04
# Epoch 152/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.4198e-04 - val_loss: 5.4030e-04
# Epoch 153/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.4131e-04 - val_loss: 5.3961e-04
# Epoch 154/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.4064e-04 - val_loss: 5.3890e-04
# Epoch 155/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.3995e-04 - val_loss: 5.3819e-04
# Epoch 156/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 5.3926e-04 - val_loss: 5.3747e-04
# Epoch 157/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.3856e-04 - val_loss: 5.3674e-04
# Epoch 158/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.3785e-04 - val_loss: 5.3600e-04
# Epoch 159/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 5.3713e-04 - val_loss: 5.3525e-04
# Epoch 160/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.3641e-04 - val_loss: 5.3450e-04
# Epoch 161/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.3567e-04 - val_loss: 5.3373e-04
# Epoch 162/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 5.3493e-04 - val_loss: 5.3296e-04
# Epoch 163/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.3418e-04 - val_loss: 5.3217e-04
# Epoch 164/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.3341e-04 - val_loss: 5.3138e-04
# Epoch 165/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.3264e-04 - val_loss: 5.3058e-04
# Epoch 166/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.3187e-04 - val_loss: 5.2977e-04
# Epoch 167/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.3108e-04 - val_loss: 5.2895e-04
# Epoch 168/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.3028e-04 - val_loss: 5.2812e-04
# Epoch 169/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.2947e-04 - val_loss: 5.2729e-04
# Epoch 170/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.2866e-04 - val_loss: 5.2644e-04
# Epoch 171/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.2783e-04 - val_loss: 5.2558e-04
# Epoch 172/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.2700e-04 - val_loss: 5.2472e-04
# Epoch 173/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.2616e-04 - val_loss: 5.2385e-04
# Epoch 174/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.2531e-04 - val_loss: 5.2296e-04
# Epoch 175/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.2444e-04 - val_loss: 5.2207e-04
# Epoch 176/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 5.2357e-04 - val_loss: 5.2117e-04
# Epoch 177/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 5.2269e-04 - val_loss: 5.2025e-04
# Epoch 178/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.2180e-04 - val_loss: 5.1933e-04
# Epoch 179/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.2091e-04 - val_loss: 5.1840e-04
# Epoch 180/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 5.2000e-04 - val_loss: 5.1746e-04
# Epoch 181/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.1908e-04 - val_loss: 5.1651e-04
# Epoch 182/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 5.1815e-04 - val_loss: 5.1555e-04
# Epoch 183/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 5.1722e-04 - val_loss: 5.1458e-04
# Epoch 184/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 5.1627e-04 - val_loss: 5.1361e-04
# Epoch 185/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.1532e-04 - val_loss: 5.1262e-04
# Epoch 186/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.1435e-04 - val_loss: 5.1162e-04
# Epoch 187/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.1338e-04 - val_loss: 5.1062e-04
# Epoch 188/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.1239e-04 - val_loss: 5.0960e-04
# Epoch 189/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.1140e-04 - val_loss: 5.0858e-04
# Epoch 190/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.1040e-04 - val_loss: 5.0754e-04
# Epoch 191/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.0939e-04 - val_loss: 5.0650e-04
# Epoch 192/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.0836e-04 - val_loss: 5.0544e-04
# Epoch 193/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.0733e-04 - val_loss: 5.0438e-04
# Epoch 194/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.0629e-04 - val_loss: 5.0331e-04
# Epoch 195/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.0524e-04 - val_loss: 5.0223e-04
# Epoch 196/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.0419e-04 - val_loss: 5.0114e-04
# Epoch 197/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.0312e-04 - val_loss: 5.0004e-04
# Epoch 198/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.0204e-04 - val_loss: 4.9893e-04
# Epoch 199/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.0096e-04 - val_loss: 4.9782e-04
# Epoch 200/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.9986e-04 - val_loss: 4.9669e-04
# Epoch 201/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.9876e-04 - val_loss: 4.9556e-04
# Epoch 202/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.9764e-04 - val_loss: 4.9441e-04
# Epoch 203/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 4.9652e-04 - val_loss: 4.9326e-04
# Epoch 204/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.9539e-04 - val_loss: 4.9210e-04
# Epoch 205/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 4.9425e-04 - val_loss: 4.9093e-04
# Epoch 206/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 4.9310e-04 - val_loss: 4.8975e-04
# Epoch 207/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 4.9194e-04 - val_loss: 4.8856e-04
# Epoch 208/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 4.9077e-04 - val_loss: 4.8737e-04
# Epoch 209/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 4.8960e-04 - val_loss: 4.8616e-04
# Epoch 210/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.8842e-04 - val_loss: 4.8495e-04
# Epoch 211/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.8722e-04 - val_loss: 4.8373e-04
# Epoch 212/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.8602e-04 - val_loss: 4.8250e-04
# Epoch 213/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 4.8481e-04 - val_loss: 4.8127e-04
# Epoch 214/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 4.8360e-04 - val_loss: 4.8002e-04
# Epoch 215/5000
# 30/30 [==============================] - 0s 13ms/step - loss:
5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.7002e-04 - val_loss: 2.6598e-04
# Epoch 365/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 2.6869e-04 - val_loss: 2.6466e-04
# Epoch 366/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.6737e-04 - val_loss: 2.6334e-04
# Epoch 367/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.6604e-04 - val_loss: 2.6203e-04
# Epoch 368/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.6472e-04 - val_loss: 2.6072e-04
# Epoch 369/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 2.6341e-04 - val_loss: 2.5941e-04
# Epoch 370/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.6210e-04 - val_loss: 2.5811e-04
# Epoch 371/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 2.6079e-04 - val_loss: 2.5681e-04
# Epoch 372/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 2.5948e-04 - val_loss: 2.5551e-04
# Epoch 373/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 2.5818e-04 - val_loss: 2.5422e-04
# Epoch 374/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 2.5688e-04 - val_loss: 2.5293e-04
# Epoch 375/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5559e-04 - val_loss: 2.5165e-04
# Epoch 376/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5429e-04 - val_loss: 2.5036e-04
# Epoch 377/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5300e-04 - val_loss: 2.4908e-04
# Epoch 378/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 2.5172e-04 - val_loss: 2.4781e-04
# Epoch 379/5000
# 30/30 [==============================] - 0s 17ms/step - loss: 2.5044e-04 - val_loss: 2.4653e-04
# Epoch 380/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4916e-04 - val_loss: 2.4527e-04
# Epoch 381/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.4788e-04 - val_loss: 2.4400e-04
# Epoch 382/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 2.4661e-04 - val_loss: 2.4274e-04
# Epoch 383/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.4534e-04 - val_loss: 2.4148e-04
# Epoch 384/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4407e-04 - val_loss: 2.4022e-04
# Epoch 385/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.4281e-04 - val_loss: 2.3897e-04
# Epoch 386/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4155e-04 - val_loss: 2.3772e-04
# Epoch 387/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4030e-04 - val_loss: 2.3647e-04
# Epoch 388/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.3904e-04 - val_loss: 2.3523e-04
# Epoch 389/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 2.3779e-04 - val_loss: 2.3399e-04
# Epoch 390/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 2.3655e-04 - val_loss: 2.3276e-04
# Epoch 391/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.3531e-04 - val_loss: 2.3152e-04
# Epoch 392/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.3407e-04 - val_loss: 2.3029e-04
# Epoch 393/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.3283e-04 - val_loss: 2.2907e-04
# Epoch 394/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.3160e-04 - val_loss: 2.2785e-04
# Epoch 395/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.3037e-04 - val_loss: 2.2663e-04
# Epoch 396/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.2915e-04 - val_loss: 2.2541e-04
# Epoch 397/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.2793e-04 - val_loss: 2.2420e-04
# Epoch 398/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.2671e-04 - val_loss: 2.2299e-04
# Epoch 399/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 2.2549e-04 - val_loss: 2.2179e-04
# Epoch 400/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 2.2428e-04 - val_loss: 2.2059e-04
# Epoch 401/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 2.2307e-04 - val_loss: 2.1939e-04
# Epoch 402/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 2.2187e-04 - val_loss: 2.1819e-04
# Epoch 403/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.2067e-04 - val_loss: 2.1700e-04
# Epoch 404/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.1947e-04 - val_loss: 2.1581e-04
# Epoch 405/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 2.1828e-04 - val_loss: 2.1463e-04
# Epoch 406/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1709e-04 - val_loss: 2.1345e-04
# Epoch 407/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 2.1590e-04 - val_loss: 2.1227e-04
# Epoch 408/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 2.1471e-04 - val_loss: 2.1110e-04
# Epoch 409/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 2.1353e-04 - val_loss: 2.0993e-04
# Epoch 410/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 2.1236e-04 - val_loss: 2.0876e-04
# Epoch 411/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.1118e-04 - val_loss: 2.0760e-04
# Epoch 412/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.1001e-04 - val_loss: 2.0644e-04
# Epoch 413/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.0885e-04 - val_loss: 2.0528e-04
# Epoch 414/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.0768e-04 - val_loss: 2.0413e-04
# Epoch 415/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.0652e-04 - val_loss: 2.0298e-04
# Epoch 416/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.0537e-04 - val_loss: 2.0183e-04
# Epoch 417/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 2.0421e-04 - val_loss: 2.0069e-04
# Epoch 418/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.0307e-04 - val_loss: 1.9955e-04
# Epoch 419/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.0192e-04 - val_loss: 1.9841e-04
# Epoch 420/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.0078e-04 - val_loss: 1.9728e-04
# Epoch 421/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 1.9964e-04 - val_loss: 1.9615e-04
# Epoch 422/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 1.9850e-04 - val_loss: 1.9503e-04
# Epoch 423/5000
# ...
# Epoch 867/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 3.7512e-09 - val_loss: 2.3811e-09
# Epoch 868/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 3.2925e-09 - val_loss: 2.0651e-09
# Epoch 869/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 2.8820e-09 - val_loss: 1.7817e-09
# Epoch 870/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5151e-09 - val_loss: 1.5297e-09
# Epoch 871/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.1877e-09 - val_loss: 1.3085e-09
# Epoch 872/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.8961e-09 - val_loss: 1.1171e-09
# Epoch 873/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.6372e-09 - val_loss: 9.5326e-10
# Epoch 874/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4086e-09 - val_loss: 8.1353e-10
# Epoch 875/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 1.2077e-09 - val_loss: 6.9367e-10
# Epoch 876/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 1.0324e-09 - val_loss: 5.9004e-10
# Epoch 877/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 8.8002e-10 - val_loss: 5.0008e-10
# Epoch 878/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 7.4823e-10 - val_loss: 4.2209e-10
# Epoch 879/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 6.3453e-10 - val_loss: 3.5476e-10
# Epoch 880/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.3667e-10 - val_loss: 2.9695e-10
# Epoch 881/5000
# 30/30 [==============================] - 1s 28ms/step - loss: 4.5261e-10 - val_loss: 2.4757e-10
# Epoch 882/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 3.8057e-10 - val_loss: 2.0561e-10
# Epoch 883/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 3.1900e-10 - val_loss: 1.7012e-10
# Epoch 884/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.6653e-10 - val_loss: 1.4024e-10
# Epoch 885/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 2.2195e-10 - val_loss: 1.1520e-10
# Epoch 886/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 1.8418e-10 - val_loss: 9.4297e-11
# Epoch 887/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 1.5230e-10 - val_loss: 7.6933e-11
# Epoch 888/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 1.2548e-10 - val_loss: 6.2566e-11
# Epoch 889/5000
# 30/30 [==============================] - 1s 28ms/step - loss: 1.0300e-10 - val_loss: 5.0726e-11
# Epoch 890/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 8.4227e-11 - val_loss: 4.1003e-11
# Epoch 891/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 6.8604e-11 - val_loss: 3.3038e-11
# Epoch 892/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.5655e-11 - val_loss: 2.6521e-11
# Epoch 893/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 4.4963e-11 - val_loss: 2.1186e-11
# Epoch 894/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 3.6169e-11 - val_loss: 1.6806e-11
# Epoch 895/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.8966e-11 - val_loss: 1.3204e-11
# Epoch 896/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 2.3093e-11 - val_loss: 1.0248e-11
# Epoch 897/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 1.8324e-11 - val_loss: 7.8567e-12
# Epoch 898/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 1.4469e-11 - val_loss: 5.9783e-12
# Epoch 899/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 1.1360e-11 - val_loss: 4.5566e-12
# Epoch 900/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 8.8571e-12 - val_loss: 3.5024e-12
# Epoch 901/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 6.8468e-12 - val_loss: 2.7035e-12
# Epoch 902/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 5.2434e-12 - val_loss: 2.0698e-12
# Epoch 903/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 3.9819e-12 - val_loss: 1.5587e-12
# Epoch 904/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 3.0049e-12 - val_loss: 1.1558e-12
# Epoch 905/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2566e-12 - val_loss: 8.4740e-13
# Epoch 906/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 1.6866e-12 - val_loss: 6.1591e-13
# Epoch 907/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 1.2537e-12 - val_loss: 4.4439e-13
# Epoch 908/5000
# 30/30 [==============================] - 1s 16ms/step - loss: 9.2657e-13 - val_loss: 3.1865e-13
# Epoch 909/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 6.8055e-13 - val_loss: 2.2732e-13
# Epoch 910/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 4.9664e-13 - val_loss: 1.6154e-13
# Epoch 911/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 3.6002e-13 - val_loss: 1.1451e-13
# Epoch 912/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 2.5922e-13 - val_loss: 8.1089e-14
# Epoch 913/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.8537e-13 - val_loss: 5.7407e-14
# Epoch 914/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 1.3165e-13 - val_loss: 4.0586e-14
# Epoch 915/5000
# 30/30 [==============================] - 1s 31ms/step - loss: 9.2841e-14 - val_loss: 2.8514e-14
# Epoch 916/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 6.4999e-14 - val_loss: 1.9694e-14
# Epoch 917/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 4.5143e-14 - val_loss: 1.3141e-14
# Epoch 918/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1055e-14 - val_loss: 8.3171e-15
# Epoch 919/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.1108e-14 - val_loss: 4.9931e-15
# Epoch 920/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 1.4122e-14 - val_loss: 2.9965e-15
# Epoch 921/5000
# 30/30 [==============================] - 1s 28ms/step - loss: 9.2575e-15 - val_loss: 1.9586e-15
# Epoch 922/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.9217e-15 - val_loss: 1.3679e-15
# Epoch 923/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 3.6957e-15 - val_loss: 9.0684e-16
# Epoch 924/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.2665e-15 - val_loss: 5.4593e-16
# Epoch 925/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 1.3798e-15 - val_loss: 3.1085e-16
# Epoch 926/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 8.3613e-16 - val_loss: 1.7296e-16
# Epoch 927/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 5.0190e-16 - val_loss: 9.4681e-17
# Epoch 928/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.9749e-16 - val_loss: 5.1402e-17
# Epoch 929/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7391e-16 - val_loss: 2.7973e-17
# Epoch 930/5000
# 30/30 [==============================] - 0s 15ms/step - loss: 1.0016e-16 - val_loss: 1.5449e-17
# Epoch 931/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 5.6810e-17 - val_loss: 8.7466e-18
# Epoch 932/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 3.1722e-17 - val_loss: 5.0672e-18
# Epoch 933/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 1.7436e-17 - val_loss: 2.9276e-18
# Epoch 934/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 9.4268e-18 - val_loss: 1.5923e-18
# Epoch 935/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 5.0016e-18 - val_loss: 7.4448e-19
# Epoch 936/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5899e-18 - val_loss: 2.7258e-19
# Epoch 937/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 1.2957e-18 - val_loss: 9.6240e-20
# Epoch 938/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 6.1688e-19 - val_loss: 6.8705e-20
# Epoch 939/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 2.7433e-19 - val_loss: 5.0999e-20
# Epoch 940/5000
# 30/30 [==============================] - 0s 16ms/step - loss: 1.1288e-19 - val_loss: 2.1928e-20
# Epoch 941/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 4.4369e-20 - val_loss: 6.5416e-21
# Epoch 942/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 1.7509e-20 - val_loss: 1.8691e-21
# Epoch 943/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 6.7831e-21 - val_loss: 5.0146e-22
# Epoch 944/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4982e-21 - val_loss: 1.3124e-22
# Epoch 945/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 8.7429e-22 - val_loss: 4.0173e-23
# Epoch 946/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.8801e-22 - val_loss: 1.6273e-23
# Epoch 947/5000
# 30/30 [==============================] - 1s 27ms/step - loss: 8.8844e-23 - val_loss: 7.3826e-24
# Epoch 948/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 2.5498e-23 - val_loss: 2.8802e-24
# Epoch 949/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 6.7487e-24 - val_loss: 7.5235e-25
# Epoch 950/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 1.6224e-24 - val_loss: 7.5829e-26
# Epoch 951/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 3.4753e-25 - val_loss: 6.0882e-27
# Epoch 952/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 6.6083e-26 - val_loss: 1.4215e-26
# Epoch 953/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 1.0557e-26 - val_loss: 2.7063e-27
# Epoch 954/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 1.0853e-27 - val_loss: 8.0705e-29
# Epoch 955/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 1.0867e-28 - val_loss: 3.6245e-30
# Epoch 956/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 7.5055e-30 - val_loss: 1.8681e-31
# Epoch 957/5000
# 30/30 [==============================] - 1s 28ms/step - loss: 2.0529e-31 - val_loss: 6.7837e-32
# Epoch 958/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.4519e-31 - val_loss: 9.0132e-32
# Epoch 959/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 8.2032e-32 - val_loss: 6.0329e-32
# Epoch 960/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 1.1328e-31 - val_loss: 1.8651e-31
# Epoch 961/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.1086e-31 - val_loss: 3.4407e-31
# Epoch 962/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 3.1712e-31 - val_loss: 1.4965e-31
# Epoch 963/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 1.4292e-31 - val_loss: 1.7865e-31
# Epoch 964/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 9.8264e-32 - val_loss: 6.0329e-32
# Epoch 965/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 3.4347e-31 - val_loss: 1.4647e-30
# Epoch 966/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 6.6864e-31 - val_loss: 2.9939e-31
# Epoch 967/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 6.2915e-31 - val_loss: 2.7073e-30
# Epoch 968/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 6.6698e-31 - val_loss: 9.1347e-31
# Epoch 969/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.8762e-31 - val_loss: 9.2207e-32
# Epoch 970/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 1.9572e-31 - val_loss: 6.0504e-32
# Epoch 971/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 1.1692e-31 - val_loss: 9.5126e-32
# Epoch 972/5000
# 30/30 [==============================] - 1s 18ms/step - loss: 5.6566e-31 - val_loss: 4.7090e-31
# Epoch 973/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 5.2248e-30 - val_loss: 1.6470e-31
# Epoch 974/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 2.8885e-29 - val_loss: 3.9322e-30
# Epoch 975/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9616e-28 - val_loss: 4.3465e-29
# Epoch 976/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 1.1093e-27 - val_loss: 7.6150e-28
# Epoch 977/5000
# 30/30 [==============================] - 1s 32ms/step - loss: 6.0682e-27 - val_loss: 6.5474e-27
# Epoch 978/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 3.0452e-26 - val_loss: 2.2099e-26
# Epoch 979/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 1.3354e-25 - val_loss: 2.4838e-26
# Epoch 980/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 4.8201e-25 - val_loss: 5.6003e-26
# Epoch 981/5000
# 30/30 [==============================] - 1s 22ms/step - loss: 1.6114e-24 - val_loss: 5.9712e-25
# Epoch 982/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 5.8943e-24 - val_loss: 4.1739e-24
# Epoch 983/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.3636e-23 - val_loss: 7.2815e-24
# Epoch 984/5000
# 30/30 [==============================] - 1s 28ms/step - loss: 8.8434e-23 - val_loss: 6.2210e-24
# Epoch 985/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 2.3841e-22 - val_loss: 1.1404e-23
# Epoch 986/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 6.2132e-22 - val_loss: 2.7371e-22
# Epoch 987/5000
# 30/30 [==============================] - 1s 26ms/step - loss: 2.7479e-21 - val_loss: 9.4321e-23
# Epoch 988/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 1.0752e-20 - val_loss: 5.5131e-22
# Epoch 989/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.9557e-20 - val_loss: 1.4193e-21
# Epoch 990/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 4.1310e-18 - val_loss: 3.2310e-17
# Epoch 991/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 5.9226e-13 - val_loss: 1.3710e-11
# Epoch 992/5000
# 30/30 [==============================] - 1s 24ms/step - loss: 1.1496e-07 - val_loss: 1.1478e-07
# Epoch 993/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 3.5523e-08 - val_loss: 2.0547e-10
# Epoch 994/5000
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2568e-08 - val_loss: 6.6099e-09
# Epoch 995/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 3.3143e-08 - val_loss: 8.2086e-09
# Epoch 996/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 3.8150e-07 - val_loss: 2.3363e-06
# Epoch 997/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 4.0163e-07 - val_loss: 4.8086e-09
# Epoch 998/5000
# 30/30 [==============================] - 0s 13ms/step - loss: 3.8855e-08 - val_loss: 1.4151e-09
# Epoch 999/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 1.0871e-08 - val_loss: 1.4445e-10
# Epoch 1000/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.7223e-09 - val_loss: 1.7380e-10
# Epoch 1001/5000
# 30/30 [==============================] - 0s 14ms/step - loss: 5.4722e-10 - val_loss: 1.4454e-10
# Epoch 1002/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 8.5299e-11 - val_loss: 1.8672e-11
# Epoch 1003/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 8.5726e-12 - val_loss: 4.5658e-13
# Epoch 1004/5000
# 30/30 [==============================] - 1s 19ms/step - loss: 8.7515e-13 - val_loss: 2.6107e-14
# Epoch 1005/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 4.1220e-14 - val_loss: 2.4227e-16
# Epoch 1006/5000
# 30/30 [==============================] - 1s 23ms/step - loss: 9.2505e-16 - val_loss: 1.1356e-17
# Epoch 1007/5000
# 30/30 [==============================] - 1s 21ms/step - loss: 2.6325e-16 - val_loss: 5.9580e-17
# Epoch 1008/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 2.5254e-17 - val_loss: 1.3643e-17
# Epoch 1009/5000
# 30/30 [==============================] - 1s 25ms/step - loss: 1.2510e-17 - val_loss: 2.5480e-19
# Cell completed at: 2023-08-28 15:29:12.588008

# %% [markdown]
# ### Loss Function Model 1
#
# n.b. This is plotted on a log scale

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.yscale("log")
    plt.legend()
    plt.show()


visualize_loss(history1, "Training and Validation Loss")

# %% [markdown]
# ## Results Model 1
#
# The following cell performs inference on the entire dataset (training and validation). The results are stored in the original dataframe as column "alpha_model1".

# %%
# Create overlapping windows of data
x_all = df_norm.filter(like="A").values
num_windows = x_all.shape[0] - past +1
windows = np.lib.stride_tricks.sliding_window_view(x_all, (past, x_all.shape[1]))

df['alpha_model1'] = np.nan

# Predict using batches and update df
batch_size_ = 32
for i in range(0, num_windows, batch_size_):
    batch_windows = windows[i:i+batch_size_]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model1.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model1'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")

print("\rprocessed: {}/{}".format(num_windows, num_windows), end="")
# Out:
# processed: 2801/2801

# %% [markdown]
# # $\alpha$ Model 1 vs Truth
#
# The top plot below shows the true $\alpha$ and the one predicted by model 1. Since the model requires 200 past timesteps, its predictions are only available for timestep 200 and later.
#
# The bottom plot shows the error (residual) bewtween $\alpha$ and the model 1 prediction.

# %%
df.plot(y=["alpha_model1", "alpha"], kind="line", grid=True, figsize=(10,3))

df["alpha_res1"] = df["alpha_model1"] - df["alpha"]
df.plot(y=["alpha_res1"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# ## Create Model 2
#
# This creates an LSTM model that uses just the model 1 output of a corrected estimated $\alpha$ as input. The LSTM model is then trained to correct the residual. The layers of model 1 are reused here, but the two trainable parameters are locked so as not no be updated by this model's training, forcing the additional layers of this model to fit to the residual.

# %%
# Lock the parameters in model 1
outputs.trainable = False

# Residual for corrected alpha
lstm_out = keras.layers.LSTM(200, activation="tanh", recurrent_activation="tanh", kernel_initializer='zeros')(inputs)
residual_out = keras.layers.Dense(1, activation="tanh", kernel_initializer='zeros')(lstm_out)

# The residual should be a small number relative to 1. Scale the value down here to put it in a reasonable range
residual_out = keras.layers.Lambda(lambda x: x * 0.10)(residual_out)

# Add model 1 and residual to make outputs for model 2
outputs2 = keras.layers.Add()([outputs, residual_out])


model2 = keras.Model(inputs=inputs, outputs=outputs2, name="model2")
model2.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model2.summary()

import datetime
# Out:
# Model: "model2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 51)]    0           []
#
#  lambda (Lambda)                (None,)              0           ['input_1[0][0]']
#
#  lstm (LSTM)                    (None, 200)          201600      ['input_1[0][0]']
#
#  reshape (Reshape)              (None, 1)            0           ['lambda[0][0]']
#
#  dense_1 (Dense)                (None, 1)            201         ['lstm[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['reshape[0][0]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['dense_1[0][0]']
#
#  add (Add)                      (None, 1)            0           ['dense[0][0]',
#                                                                   'lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 201,803
# Trainable params: 201,803
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Fit Model 2
#
# Use early stopping and save the best model to a _.h5_ file.

# %%
path_checkpoint = f"model2_checkpointv{version}.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history2 = model2.fit(
    dataset_train,
    epochs=epochs_model1,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)

print("Cell completed at:", datetime.datetime.now())
# Out:
# Epoch 1/5000
# 30/30 [==============================] - ETA: 0s - loss: 4.7128e-07
# Epoch 1: val_loss improved from inf to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 28s 836ms/step - loss: 4.7128e-07 - val_loss: 8.6696e-08
# Epoch 2/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.5611e-08
# Epoch 2: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 25s 842ms/step - loss: 2.5611e-08 - val_loss: 6.9570e-09
# Epoch 3/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.3591e-09
# Epoch 3: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 25s 839ms/step - loss: 1.3591e-09 - val_loss: 4.0363e-10
# Epoch 4/5000
# 30/30 [==============================] - ETA: 0s - loss: 8.3006e-11
# Epoch 4: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 24s 808ms/step - loss: 8.3006e-11 - val_loss: 2.4090e-11
# Epoch 5/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.6946e-11
# Epoch 5: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 23s 775ms/step - loss: 1.6946e-11 - val_loss: 4.6557e-12
# Epoch 6/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.0367e-11
# Epoch 6: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 24s 800ms/step - loss: 1.0367e-11 - val_loss: 2.4252e-12
# Epoch 7/5000
# 30/30 [==============================] - ETA: 0s - loss: 7.0919e-12
# Epoch 7: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 25s 851ms/step - loss: 7.0919e-12 - val_loss: 1.2723e-12
# Epoch 8/5000
# 30/30 [==============================] - ETA: 0s - loss: 4.8807e-12
# Epoch 8: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 24s 785ms/step - loss: 4.8807e-12 - val_loss: 4.5852e-13
# Epoch 9/5000
# 30/30 [==============================] - ETA: 0s - loss: 3.1578e-12
# Epoch 9: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 836ms/step - loss: 3.1578e-12 - val_loss: 5.7073e-13
# Epoch 10/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.3173e-12
# Epoch 10: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 22s 729ms/step - loss: 1.3173e-12 - val_loss: 1.0595e-13
# Epoch 11/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.2094e-13
# Epoch 11: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 26s 866ms/step - loss: 6.2094e-13 - val_loss: 2.7327e-14
# Epoch 12/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.3181e-13
# Epoch 12: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 843ms/step - loss: 2.3181e-13 - val_loss: 5.6112e-14
# Epoch 13/5000
# 30/30 [==============================] - ETA: 0s - loss: 4.6217e-14
# Epoch 13: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 28s 924ms/step - loss: 4.6217e-14 - val_loss: 4.2414e-15
# Epoch 14/5000
# 30/30 [==============================] - ETA: 0s - loss: 4.1422e-15
# Epoch 14: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 24s 796ms/step - loss: 4.1422e-15 - val_loss: 2.9269e-15
# Epoch 15/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.5834e-15
# Epoch 15: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 818ms/step - loss: 1.5834e-15 - val_loss: 3.8768e-15
# Epoch 16/5000
# 30/30 [==============================] - ETA: 0s - loss: 8.9784e-16
# Epoch 16: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 828ms/step - loss: 8.9784e-16 - val_loss: 3.4182e-15
# Epoch 17/5000
# 30/30 [==============================] - ETA: 0s - loss: 3.9947e-16
# Epoch 17: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 25s 835ms/step - loss: 3.9947e-16 - val_loss: 8.4656e-16
# Epoch 18/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.1383e-16
# Epoch 18: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 26s 877ms/step - loss: 1.1383e-16 - val_loss: 5.7807e-17
# Epoch 19/5000
# 30/30 [==============================] - ETA: 0s - loss: 4.4194e-16
# Epoch 19: val_loss improved from 0.00000 to 0.00000, saving model to model2_checkpointv5.h5
# 30/30 [==============================] - 25s 847ms/step - loss: 4.4194e-16 - val_loss: 9.1925e-18
# Epoch 20/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.3078e-15
# Epoch 20: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 844ms/step - loss: 2.3078e-15 - val_loss: 6.2812e-16
# Epoch 21/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.0224e-14
# Epoch 21: val_loss did not improve from 0.00000
# 30/30 [==============================] - 25s 848ms/step - loss: 1.0224e-14 - val_loss: 1.0618e-14
# Epoch 22/5000
# 30/30 [==============================] - ETA: 0s - loss: 4.7169e-14
# Epoch 22: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 855ms/step - loss: 4.7169e-14 - val_loss: 3.8035e-15
# Epoch 23/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.4158e-13
# Epoch 23: val_loss did not improve from 0.00000
# 30/30 [==============================] - 26s 878ms/step - loss: 1.4158e-13 - val_loss: 7.0469e-14
# Epoch 24/5000
# 30/30 [==============================] - ETA: 0s - loss: 5.0758e-13
# Epoch 24: val_loss did not improve from 0.00000
# 30/30 [==============================] - 27s 917ms/step - loss: 5.0758e-13 - val_loss: 3.7735e-14
# Epoch 25/5000
# 30/30 [==============================] - ETA: 0s - loss: 1
val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 741ms/step - loss: 8.4314e-08 - val_loss: 4.6402e-08
# Epoch 128/5000
# 30/30 [==============================] - ETA: 0s - loss: 9.6694e-07
# Epoch 128: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 723ms/step - loss: 9.6694e-07 - val_loss: 8.8050e-07
# Epoch 129/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.3198e-07
# Epoch 129: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 723ms/step - loss: 2.3198e-07 - val_loss: 5.0807e-08
# Epoch 130/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.1304e-08
# Epoch 130: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 726ms/step - loss: 1.1304e-08 - val_loss: 1.5052e-09
# Epoch 131/5000
# 30/30 [==============================] - ETA: 0s - loss: 3.2265e-09
# Epoch 131: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 788ms/step - loss: 3.2265e-09 - val_loss: 2.1236e-10
# Epoch 132/5000
# 30/30 [==============================] - ETA: 0s - loss: 7.9868e-10
# Epoch 132: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 726ms/step - loss: 7.9868e-10 - val_loss: 4.4747e-11
# Epoch 133/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.9726e-10
# Epoch 133: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 728ms/step - loss: 2.9726e-10 - val_loss: 1.9017e-11
# Epoch 134/5000
# 30/30 [==============================] - ETA: 0s - loss: 8.7320e-11
# Epoch 134: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 775ms/step - loss: 8.7320e-11 - val_loss: 7.7184e-12
# Epoch 135/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.4511e-11
# Epoch 135: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 747ms/step - loss: 2.4511e-11 - val_loss: 2.8579e-12
# Epoch 136/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.4413e-12
# Epoch 136: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 756ms/step - loss: 6.4413e-12 - val_loss: 6.4867e-13
# Epoch 137/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.5279e-12
# Epoch 137: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 759ms/step - loss: 1.5279e-12 - val_loss: 3.9617e-14
# Epoch 138/5000
# 30/30 [==============================] - ETA: 0s - loss: 3.2048e-13
# Epoch 138: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 785ms/step - loss: 3.2048e-13 - val_loss: 1.5890e-14
# Epoch 139/5000
# 30/30 [==============================] - ETA: 0s - loss: 5.9157e-14
# Epoch 139: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 778ms/step - loss: 5.9157e-14 - val_loss: 1.6034e-14
# Epoch 140/5000
# 30/30 [==============================] - ETA: 0s - loss: 8.5869e-15
# Epoch 140: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 774ms/step - loss: 8.5869e-15 - val_loss: 1.6828e-15
# Epoch 141/5000
# 30/30 [==============================] - ETA: 0s - loss: 7.9450e-16
# Epoch 141: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 794ms/step - loss: 7.9450e-16 - val_loss: 3.2933e-17
# Epoch 142/5000
# 30/30 [==============================] - ETA: 0s - loss: 8.3910e-17
# Epoch 142: val_loss did not improve from 0.00000
# 30/30 [==============================] - 23s 757ms/step - loss: 8.3910e-17 - val_loss: 2.1821e-18
# Epoch 143/5000
# 30/30 [==============================] - ETA: 0s - loss: 3.1643e-18
# Epoch 143: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 799ms/step - loss: 3.1643e-18 - val_loss: 3.5349e-20
# Epoch 144/5000
# 30/30 [==============================] - ETA: 0s - loss: 7.9404e-20
# Epoch 144: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 745ms/step - loss: 7.9404e-20 - val_loss: 1.6427e-21
# Epoch 145/5000
# 30/30 [==============================] - ETA: 0s - loss: 3.0034e-20
# Epoch 145: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 733ms/step - loss: 3.0034e-20 - val_loss: 8.0909e-21
# Epoch 146/5000
# 30/30 [==============================] - ETA: 0s - loss: 2.7736e-21
# Epoch 146: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 746ms/step - loss: 2.7736e-21 - val_loss: 1.7019e-21
# Epoch 147/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.6778e-21
# Epoch 147: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 734ms/step - loss: 1.6778e-21 - val_loss: 5.4358e-23
# Epoch 148/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5133e-22
# Epoch 148: val_loss did not improve from 0.00000
# 30/30 [==============================] - 24s 803ms/step - loss: 6.5133e-22 - val_loss: 4.2062e-23
# Epoch 149/5000
# 30/30 [==============================] - ETA: 0s - loss: 1.4439e-22
# Epoch 149: val_loss did not improve from 0.00000
# 30/30 [==============================] - 22s 723ms/step - loss: 1.4439e-22 - val_loss: 1.3035e-22
# Cell completed at: 2023-08-28 16:33:55.464989

# %% [markdown]
# ### Loss Function Model 2
#
# n.b. This is plotted on a log scale

# %%
visualize_loss(history2, "Training and Validation Loss")

# %% [markdown]
# ## Results Model 2
#
# The following cell performs inference on the entire dataset (training and validation). The results are stored in the original dataframe as column "alpha_model2".

# %%
df['alpha_model2'] = np.nan

# Predict using batches and update df
batch_size_ = 32
for i in range(0, num_windows, batch_size_):
    batch_windows = windows[i:i+batch_size_]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model2.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model2'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")

print("\rprocessed: {}/{}".format(num_windows, num_windows), end="")
# Out:
# processed: 2801/2801

# %% [markdown]
# # $\alpha$ Model 2 vs Truth
#
# The top plot below shows the true $\alpha$ and the one predicted by model 2. Since the model requires 200 past timesteps, its predictions are only available for timestep 200 and later.
#
# The bottom plot shows the error (residual) bewtween $\alpha$ and the model 2 prediction.

# %%
df.plot(y=["alpha_model1", "alpha", "alpha_model2"], kind="line", grid=True, figsize=(10,3))

df["alpha_res2"] = df["alpha_model2"] - df["alpha"]
df.plot(y=["alpha_res1", "alpha_res2"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# # Basement
# <hr>

# %% [markdown]
# ### Example predictions
#
# Plot a few examples showing the $\alpha$ truth history and the model prediction. This is also carried over from the keras weather example. The red "X" is just the last point in the truth history since here, we are not trying to predict the future, only use the past to predict the present.
#
# n.b. Unlike the original example for the weather which included Temperature in the features and was used to predict Temperature in the future, this problem does not directly measure $\alpha$. Thus these blue points are useful to guide the human eye, but are not values the model sees.
#
# The first 3 plots are from the validation set while the second three are from the training set.

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future_ = delta
    else:
        future_ = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future_, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend(loc="upper left")
    plt.xlim([time_steps[0], (future_ + 5) * 2])
    plt.ylim([0.90, 1.10])
    plt.xlabel("Time-Step")
    plt.show()
    return

# This has the alpha history with last point being the same as the label
alpha_valid = df_valid_labels.filter(items=["alpha"])[:-(past+future)].values
alpha_train = df_train_labels.filter(items=["alpha"])[:-(past+future)].values

 
# Validation examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_valid[start:start+past], 0)
    y_history = alpha_valid[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model2.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from Validation Set")

# Training examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_train[start:start+past], 0)
    y_history = alpha_train[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model2.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from training Set")
# Out:
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 111ms/step
