# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

filename = '/work/epsci/davidl/2023.08.18.AIEC_LSTM_simulation/fcal2.csv'

df = pd.read_csv(filename)

# Rename columns from "bX" to "AX" to better align with what we say vocally
name_map = {}
for i in range(1,51):
    name_map['b'+str(i)] = 'A'+str(i)
df = df.rename(columns=name_map)

# Calculate alpha (should work for any pair)
df['alpha'] = df['A17']/df['g17']

# %%
split_fraction = 0.80
train_split = int(split_fraction * int(df.shape[0]))
step = 1

past = 200   # number of timesteps in the past to use for predicting value(s) for current timestep
future = 0   # number of timesteps in the future to predict value for
learning_rate = 0.002
batch_size = 25
epochs = 100

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std


# Create nomalized training and validation sets
# df_norm  = normalize(df, train_split)  # This gives really bad model fits! Do not use!
df_norm  = df
df_train = df_norm[:train_split-1]
df_valid = df_norm[train_split:]
df_train_labels = df[:train_split-1]  # unormalized!
df_valid_labels = df[train_split:]    # unormalized!

# Chop off ends so we have a full set of past elements and corresponding future
x_train = df_train.filter(like="A").values
y_train = df_train_labels.filter(items=["alpha"])[past+future-1:].values
x_valid = df_valid.filter(like="A").values
y_valid = df_valid_labels.filter(items=["alpha"])[past+future-1:].values
print("x_train shape: "+str(x_train.shape) + "   y_train shape: "+str(y_train.shape))
print("x_valid shape: "+str(x_valid.shape) + "   y_valid shape: "+str(y_valid.shape))
# Out:
# x_train shape: (2399, 50)   y_train shape: (2200, 1)
# x_valid shape: (600, 50)   y_valid shape: (401, 1)

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_train.take(1): train_inputs, train_targets = batch
print("  Training: Input shape:", train_inputs.numpy().shape, " Target shape:" , train_targets.numpy().shape)

dataset_valid = keras.preprocessing.timeseries_dataset_from_array(
    x_valid,
    y_valid,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_valid.take(1): valid_inputs, valid_targets = batch
print("Validation: Input shape:", valid_inputs.numpy().shape, " Target shape:" , valid_targets.numpy().shape)
# Out:
#   Training: Input shape: (25, 200, 50)  Target shape: (25, 1)
# Validation: Input shape: (25, 200, 50)  Target shape: (25, 1)

# %%
inputs = keras.layers.Input(shape=(train_inputs.shape[1], train_inputs.shape[2]))
lstm_out = keras.layers.LSTM(200)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 200, 50)]         0
#
#  lstm_2 (LSTM)               (None, 200)               200800
#
#  dense_2 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 201001 (785.16 KB)
# Trainable params: 201001 (785.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=20)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/100
# 88/88 [==============================] - ETA: 0s - loss: 2.5362e-04
# Epoch 1: val_loss improved from inf to 0.00009, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 190ms/step - loss: 2.5362e-04 - val_loss: 8.5171e-05
# Epoch 2/100
# 88/88 [==============================] - ETA: 0s - loss: 2.9175e-04
# Epoch 2: val_loss improved from 0.00009 to 0.00009, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 187ms/step - loss: 2.9175e-04 - val_loss: 8.5155e-05
# Epoch 3/100
# 88/88 [==============================] - ETA: 0s - loss: 3.2046e-04
# Epoch 3: val_loss improved from 0.00009 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 3.2046e-04 - val_loss: 8.4259e-05
# Epoch 4/100
# 88/88 [==============================] - ETA: 0s - loss: 3.3750e-04
# Epoch 4: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 183ms/step - loss: 3.3750e-04 - val_loss: 8.3403e-05
# Epoch 5/100
# 88/88 [==============================] - ETA: 0s - loss: 3.4545e-04
# Epoch 5: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 181ms/step - loss: 3.4545e-04 - val_loss: 8.2750e-05
# Epoch 6/100
# 88/88 [==============================] - ETA: 0s - loss: 3.4800e-04
# Epoch 6: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 184ms/step - loss: 3.4800e-04 - val_loss: 8.2053e-05
# Epoch 7/100
# 88/88 [==============================] - ETA: 0s - loss: 3.4759e-04
# Epoch 7: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 3.4759e-04 - val_loss: 8.1157e-05
# Epoch 8/100
# 88/88 [==============================] - ETA: 0s - loss: 3.4542e-04
# Epoch 8: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 3.4542e-04 - val_loss: 8.0040e-05
# Epoch 9/100
# 88/88 [==============================] - ETA: 0s - loss: 3.4216e-04
# Epoch 9: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 187ms/step - loss: 3.4216e-04 - val_loss: 7.8731e-05
# Epoch 10/100
# 88/88 [==============================] - ETA: 0s - loss: 3.3824e-04
# Epoch 10: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 184ms/step - loss: 3.3824e-04 - val_loss: 7.7265e-05
# Epoch 11/100
# 88/88 [==============================] - ETA: 0s - loss: 3.3392e-04
# Epoch 11: val_loss improved from 0.00008 to 0.00008, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 178ms/step - loss: 3.3392e-04 - val_loss: 7.5673e-05
# Epoch 12/100
# 88/88 [==============================] - ETA: 0s - loss: 3.2935e-04
# Epoch 12: val_loss improved from 0.00008 to 0.00007, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 183ms/step - loss: 3.2935e-04 - val_loss: 7.3984e-05
# Epoch 13/100
# 88/88 [==============================] - ETA: 0s - loss: 3.2465e-04
# Epoch 13: val_loss improved from 0.00007 to 0.00007, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 3.2465e-04 - val_loss: 7.2231e-05
# Epoch 14/100
# 88/88 [==============================] - ETA: 0s - loss: 3.1988e-04
# Epoch 14: val_loss improved from 0.00007 to 0.00007, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 181ms/step - loss: 3.1988e-04 - val_loss: 7.0439e-05
# Epoch 15/100
# 88/88 [==============================] - ETA: 0s - loss: 3.1507e-04
# Epoch 15: val_loss improved from 0.00007 to 0.00007, saving model to model_checkpoint.h5
# 88/88 [==============================] - 18s 209ms/step - loss: 3.1507e-04 - val_loss: 6.8628e-05
# Epoch 16/100
# 88/88 [==============================] - ETA: 0s - loss: 3.1025e-04
# Epoch 16: val_loss improved from 0.00007 to 0.00007, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 183ms/step - loss: 3.1025e-04 - val_loss: 6.6816e-05
# Epoch 17/100
# 88/88 [==============================] - ETA: 0s - loss: 3.0544e-04
# Epoch 17: val_loss improved from 0.00007 to 0.00007, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 180ms/step - loss: 3.0544e-04 - val_loss: 6.5018e-05
# Epoch 18/100
# 88/88 [==============================] - ETA: 0s - loss: 3.0065e-04
# Epoch 18: val_loss improved from 0.00007 to 0.00006, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 185ms/step - loss: 3.0065e-04 - val_loss: 6.3242e-05
# Epoch 19/100
# 88/88 [==============================] - ETA: 0s - loss: 2.9587e-04
# Epoch 19: val_loss improved from 0.00006 to 0.00006, saving model to model_checkpoint.h5
# 88/88 [==============================] - 45s 513ms/step - loss: 2.9587e-04 - val_loss: 6.1504e-05
# Epoch 20/100
# 88/88 [==============================] - ETA: 0s - loss: 2.9112e-04
# Epoch 20: val_loss improved from 0.00006 to 0.00006, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 185ms/step - loss: 2.9112e-04 - val_loss: 5.9803e-05
# Epoch 21/100
# 88/88 [==============================] - ETA: 0s - loss: 2.8640e-04
# Epoch 21: val_loss improved from 0.00006 to 0.00006, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 2.8640e-04 - val_loss: 5.8151e-05
# Epoch 22/100
# 88/88 [==============================] - ETA: 0s - loss: 2.8170e-04
# Epoch 22: val_loss improved from 0.00006 to 0.00006, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 182ms/step - loss: 2.8170e-04 - val_loss: 5.6549e-05
# Epoch 23/100
# 88/88 [==============================] - ETA: 0s - loss: 2.7703e-04
# Epoch 23: val_loss improved from 0.00006 to 0.00006, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 2.7703e-04 - val_loss: 5.5001e-05
# Epoch 24/100
# 88/88 [==============================] - ETA: 0s - loss: 2.7238e-04
# Epoch 24: val_loss improved from 0.00006 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 182ms/step - loss: 2.7238e-04 - val_loss: 5.3509e-05
# Epoch 25/100
# 88/88 [==============================] - ETA: 0s - loss: 2.6775e-04
# Epoch 25: val_loss improved from 0.00005 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 34s 390ms/step - loss: 2.6775e-04 - val_loss: 5.2078e-05
# Epoch 26/100
# 88/88 [==============================] - ETA: 0s - loss: 2.6316e-04
# Epoch 26: val_loss improved from 0.00005 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 37s 422ms/step - loss: 2.6316e-04 - val_loss: 5.0701e-05
# Epoch 27/100
# 88/88 [==============================] - ETA: 0s - loss: 2.5858e-04
# Epoch 27: val_loss improved from 0.00005 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 2.5858e-04 - val_loss: 4.9385e-05
# Epoch 28/100
# 88/88 [==============================] - ETA: 0s - loss: 2.5402e-04
# Epoch 28: val_loss improved from 0.00005 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 48s 552ms/step - loss: 2.5402e-04 - val_loss: 4.8132e-05
# Epoch 29/100
# 88/88 [==============================] - ETA: 0s - loss: 2.4949e-04
# Epoch 29: val_loss improved from 0.00005 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 24s 271ms/step - loss: 2.4949e-04 - val_loss: 4.6936e-05
# Epoch 30/100
# 88/88 [==============================] - ETA: 0s - loss: 2.4499e-04
# Epoch 30: val_loss improved from 0.00005 to 0.00005, saving model to model_checkpoint.h5
# 88/88 [==============================] - 117s 1s/step - loss: 2.4499e-04 - val_loss: 4.5802e-05
# Epoch 31/100
# 88/88 [==============================] - ETA: 0s - loss: 2.4050e-04
# Epoch 31: val_loss improved from 0.00005 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 198ms/step - loss: 2.4050e-04 - val_loss: 4.4732e-05
# Epoch 32/100
# 88/88 [==============================] - ETA: 0s - loss: 2.3605e-04
# Epoch 32: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 39s 450ms/step - loss: 2.3605e-04 - val_loss: 4.3729e-05
# Epoch 33/100
# 88/88 [==============================] - ETA: 0s - loss: 2.3162e-04
# Epoch 33: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 34s 387ms/step - loss: 2.3162e-04 - val_loss: 4.2797e-05
# Epoch 34/100
# 88/88 [==============================] - ETA: 0s - loss: 2.2727e-04
# Epoch 34: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 38s 433ms/step - loss: 2.2727e-04 - val_loss: 4.1940e-05
# Epoch 35/100
# 88/88 [==============================] - ETA: 0s - loss: 2.2306e-04
# Epoch 35: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 33s 377ms/step - loss: 2.2306e-04 - val_loss: 4.1142e-05
# Epoch 36/100
# 88/88 [==============================] - ETA: 0s - loss: 2.1908e-04
# Epoch 36: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 37s 424ms/step - loss: 2.1908e-04 - val_loss: 4.0362e-05
# Epoch 37/100
# 88/88 [==============================] - ETA: 0s - loss: 2.1535e-04
# Epoch 37: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 65s 746ms/step - loss: 2.1535e-04 - val_loss: 3.9551e-05
# Epoch 38/100
# 88/88 [==============================] - ETA: 0s - loss: 2.1168e-04
# Epoch 38: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 208s 2s/step - loss: 2.1168e-04 - val_loss: 3.8722e-05
# Epoch 39/100
# 88/88 [==============================] - ETA: 0s - loss: 2.0791e-04
# Epoch 39: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 190ms/step - loss: 2.0791e-04 - val_loss: 3.7940e-05
# Epoch 40/100
# 88/88 [==============================] - ETA: 0s - loss: 2.0410e-04
# Epoch 40: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 41s 470ms/step - loss: 2.0410e-04 - val_loss: 3.7220e-05
# Epoch 41/100
# 88/88 [==============================] - ETA: 0s - loss: 2.0037e-04
# Epoch 41: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 189ms/step - loss: 2.0037e-04 - val_loss: 3.6545e-05
# Epoch 42/100
# 88/88 [==============================] - ETA: 0s - loss: 1.9674e-04
# Epoch 42: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 21s 242ms/step - loss: 1.9674e-04 - val_loss: 3.5908e-05
# Epoch 43/100
# 88/88 [==============================] - ETA: 0s - loss: 1.9319e-04
# Epoch 43: val_loss improved from 0.00004 to 0.00004, saving model to model_checkpoint.h5
# 88/88 [==============================] - 20s 228ms/step - loss: 1.9319e-04 - val_loss: 3.5316e-05
# Epoch 44/100
# 88/88 [==============================] - ETA: 0s - loss: 1.8975e-04
# Epoch 44: val_loss improved from 0.00004 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 185ms/step - loss: 1.8975e-04 - val_loss: 3.4763e-05
# Epoch 45/100
# 88/88 [==============================] - ETA: 0s - loss: 1.8642e-04
# Epoch 45: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 34s 385ms/step - loss: 1.8642e-04 - val_loss: 3.4247e-05
# Epoch 46/100
# 88/88 [==============================] - ETA: 0s - loss: 1.8318e-04
# Epoch 46: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 183ms/step - loss: 1.8318e-04 - val_loss: 3.3766e-05
# Epoch 47/100
# 88/88 [==============================] - ETA: 0s - loss: 1.8005e-04
# Epoch 47: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 36s 414ms/step - loss: 1.8005e-04 - val_loss: 3.3320e-05
# Epoch 48/100
# 88/88 [==============================] - ETA: 0s - loss: 1.7702e-04
# Epoch 48: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 30s 344ms/step - loss: 1.7702e-04 - val_loss: 3.2908e-05
# Epoch 49/100
# 88/88 [==============================] - ETA: 0s - loss: 1.7410e-04
# Epoch 49: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 191ms/step - loss: 1.7410e-04 - val_loss: 3.2528e-05
# Epoch 50/100
# 88/88 [==============================] - ETA: 0s - loss: 1.7128e-04
# Epoch 50: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 189ms/step - loss: 1.7128e-04 - val_loss: 3.2180e-05
# Epoch 51/100
# 88/88 [==============================] - ETA: 0s - loss: 1.6857e-04
# Epoch 51: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 42s 478ms/step - loss: 1.6857e-04 - val_loss: 3.1861e-05
# Epoch 52/100
# 88/88 [==============================] - ETA: 0s - loss: 1.6595e-04
# Epoch 52: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 39s 447ms/step - loss: 1.6595e-04 - val_loss: 3.1572e-05
# Epoch 53/100
# 88/88 [==============================] - ETA: 0s - loss: 1.6344e-04
# Epoch 53: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 1.6344e-04 - val_loss: 3.1311e-05
# Epoch 54/100
# 88/88 [==============================] - ETA: 0s - loss: 1.6102e-04
# Epoch 54: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 191ms/step - loss: 1.6102e-04 - val_loss: 3.1079e-05
# Epoch 55/100
# 88/88 [==============================] - ETA: 0s - loss: 1.5869e-04
# Epoch 55: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 46s 529ms/step - loss: 1.5869e-04 - val_loss: 3.0873e-05
# Epoch 56/100
# 88/88 [==============================] - ETA: 0s - loss: 1.5646e-04
# Epoch 56: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 30s 343ms/step - loss: 1.5646e-04 - val_loss: 3.0694e-05
# Epoch 57/100
# 88/88 [==============================] - ETA: 0s - loss: 1.5431e-04
# Epoch 57: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 190ms/step - loss: 1.5431e-04 - val_loss: 3.0541e-05
# Epoch 58/100
# 88/88 [==============================] - ETA: 0s - loss: 1.5224e-04
# Epoch 58: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 187ms/step - loss: 1.5224e-04 - val_loss: 3.0412e-05
# Epoch 59/100
# 88/88 [==============================] - ETA: 0s - loss: 1.5025e-04
# Epoch 59: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 186ms/step - loss: 1.5025e-04 - val_loss: 3.0309e-05
# Epoch 60/100
# 88/88 [==============================] - ETA: 0s - loss: 1.4834e-04
# Epoch 60: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 16s 187ms/step - loss: 1.4834e-04 - val_loss: 3.0229e-05
# Epoch 61/100
# 88/88 [==============================] - ETA: 0s - loss: 1.4650e-04
# Epoch 61: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 23s 266ms/step - loss: 1.4650e-04 - val_loss: 3.0172e-05
# Epoch 62/100
# 88/88 [==============================] - ETA: 0s - loss: 1.4472e-04
# Epoch 62: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 17s 191ms/step - loss: 1.4472e-04 - val_loss: 3.0138e-05
# Epoch 63/100
# 88/88 [==============================] - ETA: 0s - loss: 1.4300e-04
# Epoch 63: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint.h5
# 88/88 [==============================] - 33s 376ms/step - loss: 1.4300e-04 - val_loss: 3.0126e-05
# Epoch 64/100
# 88/88 [==============================] - ETA: 0s - loss: 1.4134e-04
# Epoch 64: val_loss did not improve from 0.00003
# 88/88 [==============================] - 17s 192ms/step - loss: 1.4134e-04 - val_loss: 3.0136e-05
# Epoch 65/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3973e-04
# Epoch 65: val_loss did not improve from 0.00003
# 88/88 [==============================] - 17s 188ms/step - loss: 1.3973e-04 - val_loss: 3.0166e-05
# Epoch 66/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3818e-04
# Epoch 66: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 186ms/step - loss: 1.3818e-04 - val_loss: 3.0218e-05
# Epoch 67/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3669e-04
# Epoch 67: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 184ms/step - loss: 1.3669e-04 - val_loss: 3.0294e-05
# Epoch 68/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3526e-04
# Epoch 68: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 183ms/step - loss: 1.3526e-04 - val_loss: 3.0397e-05
# Epoch 69/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3389e-04
# Epoch 69: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 182ms/step - loss: 1.3389e-04 - val_loss: 3.0531e-05
# Epoch 70/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3259e-04
# Epoch 70: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 185ms/step - loss: 1.3259e-04 - val_loss: 3.0693e-05
# Epoch 71/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3135e-04
# Epoch 71: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 182ms/step - loss: 1.3135e-04 - val_loss: 3.0884e-05
# Epoch 72/100
# 88/88 [==============================] - ETA: 0s - loss: 1.3014e-04
# Epoch 72: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 181ms/step - loss: 1.3014e-04 - val_loss: 3.1104e-05
# Epoch 73/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2896e-04
# Epoch 73: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 186ms/step - loss: 1.2896e-04 - val_loss: 3.1345e-05
# Epoch 74/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2778e-04
# Epoch 74: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 187ms/step - loss: 1.2778e-04 - val_loss: 3.1608e-05
# Epoch 75/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2662e-04
# Epoch 75: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 183ms/step - loss: 1.2662e-04 - val_loss: 3.1892e-05
# Epoch 76/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2547e-04
# Epoch 76: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 182ms/step - loss: 1.2547e-04 - val_loss: 3.2195e-05
# Epoch 77/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2432e-04
# Epoch 77: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 183ms/step - loss: 1.2432e-04 - val_loss: 3.2521e-05
# Epoch 78/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2319e-04
# Epoch 78: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 182ms/step - loss: 1.2319e-04 - val_loss: 3.2864e-05
# Epoch 79/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2208e-04
# Epoch 79: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 184ms/step - loss: 1.2208e-04 - val_loss: 3.3227e-05
# Epoch 80/100
# 88/88 [==============================] - ETA: 0s - loss: 1.2099e-04
# Epoch 80: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 184ms/step - loss: 1.2099e-04 - val_loss: 3.3608e-05
# Epoch 81/100
# 88/88 [==============================] - ETA: 0s - loss: 1.1994e-04
# Epoch 81: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 186ms/step - loss: 1.1994e-04 - val_loss: 3.4014e-05
# Epoch 82/100
# 88/88 [==============================] - ETA: 0s - loss: 1.1893e-04
# Epoch 82: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 182ms/step - loss: 1.1893e-04 - val_loss: 3.4454e-05
# Epoch 83/100
# 88/88 [==============================] - ETA: 0s - loss: 1.1794e-04
# Epoch 83: val_loss did not improve from 0.00003
# 88/88 [==============================] - 16s 186ms/step - loss: 1.1794e-04 - val_loss: 3.4906e-05

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.yscale("log")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future_ = delta
    else:
        future_ = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future_, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend(loc="upper left")
    plt.xlim([time_steps[0], (future_ + 5) * 2])
    plt.ylim([0.85, 1.050])
    plt.xlabel("Time-Step")
    plt.show()
    return

# This has the alpha history with last point being the same as the label
alpha_valid = df_valid_labels.filter(items=["alpha"])[:-(past+future)].values
alpha_train = df_train_labels.filter(items=["alpha"])[:-(past+future)].values

# y_history = alpha_valid[0:0+past]
# # print('x_train:', x_valid[25:30, 16])
# print('y_valid:', y_valid[0:5, :], ' y_history[-1]:',y_history[-1])

# start = 0
# for x, y in dataset_valid.take(5):

#     for i in range(x.shape[0]):
#         if i<3 or i>20:
#             # print(start, i,'.',i, ' x[',i,'][0:4][:,16]', x[i,0:4,16])
#             print(start, i,'.',i, ' y[',i,',:]', y[i,:])
    
#     s = start*batch_size
#     y_history = alpha_valid[s:s+past]
#     print('last_history:', y_history[-1], '  y_label:',y[0])
#     # start += 1
#     show_plot(
#         [y_history, y[0].numpy(), model.predict(x)[0]],
#         0,
#         "Data Set (Validation)",
#     )
#     start += 1
 
# Validation examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_valid[start:start+past], 0)
    y_history = alpha_valid[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from Validation Set")

# Training examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_train[start:start+past], 0)
    y_history = alpha_train[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from training Set")
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step

# %%
# Create overlapping windows of data
x_all = df_norm.filter(like="A").values
num_windows = x_all.shape[0] - past +1
windows = np.lib.stride_tricks.sliding_window_view(x_all, (past, x_all.shape[1]))

df['alpha_model'] = np.nan

# Predict using batches and update df
batch_size = 32
for i in range(0, num_windows, batch_size):
    batch_windows = windows[i:i+batch_size]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")
# Out:
# processed: 2784/2801

# %%
df.plot(y=["alpha_model", "alpha"], kind="line", grid=True, figsize=(10,3))

df["alpha_res"] = df["alpha_model"] - df["alpha"]
df.plot(y=["alpha_res"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >
