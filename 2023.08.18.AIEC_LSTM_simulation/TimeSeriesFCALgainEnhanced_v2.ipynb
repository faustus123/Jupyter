# %% [markdown]
# # FCAL Simulation $\alpha$ fitting with LSTM Model
#
#
# This is a copy of the TimeSeriesFCALgainEnhanced.ipynb notebook, but using the fcal_DLv2.csv file as input. That file was generated by a run of the GenerateDataset.ipynb notebook. It differes from Mike's data set primarily in that it uses a sin^2 function instead of a sawtooth function for $\alpha$
# <hr>
#
# This is mostly a copy of the TimeSeriesFCALgain.ipynb notebook except it uses the mean of all "A" values at each time step as an estimate of the $\alpha$ value which is included as an extra input. In other words, the model takes 51 inputs instead of 50 with the 51st just being the average of the other 50.
#
# Note that the estimated $\alpha$ is used as both an input feature to the LSTM model (calculated for each time step), but the value at the current time step is added to the LSTM output. This forces the actual LSTM layers to predict the _residual_ of $\alpha$ which gives a more accurate solution.
#
# <hr>
#
# <s>This notebook uses the FCAL simulation data Mike produced with a uniform sawtooth $\alpha$.</s>
#
# This fits an LSTM model using the 50 "A" values as inputs with a 200 time step history to predict the value of $\alpha$ of the current time step.
#
# This is based on the keras Timeseries example for weather forecasting found here:
# https://keras.io/examples/timeseries/timeseries_weather_forecasting
#
#
# This first cell just reads the data, renames the "b*" columns to "A*", and calculates the true $\alpha$, adding it to the dataframe.

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

filename = 'fcal_DLv2.csv'

df = pd.read_csv(filename)

# Rename columns from "bX" to "AX" to better align with what we say vocally
name_map = {}
for i in range(1,51):
    name_map['b'+str(i)] = 'A'+str(i)
df = df.rename(columns=name_map)

# Calculate alpha (should work for any pair)
df['alpha'] = df['A23']/df['g23']


df['Aalpha_est'] = df.filter(like="A").mean(axis=1)

print("Cell completed at:", datetime.datetime.now())
# Out:
# 2023-08-28 08:10:37.167258: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-28 08:10:37.224416: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-28 08:10:37.226121: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-28 08:10:38.355753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cell completed at: 2023-08-28 08:10:39.653251

# %% [markdown]
# ## Prepare training and validation sets
#
# This will split the data into training and validation sets. Note that the normalization function (copied from the original keras example) is not used since it seemed to result in much worse model fits. This is not such an issue for this data set since the values are already in a small range around 1.

# %%
split_fraction = 0.70
train_split = int(split_fraction * int(df.shape[0]))
step = 1

past = 200   # number of timesteps in the past to use for predicting value(s) for current timestep
future = 0   # number of timesteps in the future to predict value for
learning_rate = 0.002
batch_size = 64
epochs_model1 = 5000
epochs_model2 = 200

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std


# Create nomalized training and validation sets
# df_norm  = normalize(df, train_split)  # This gives really bad model fits! Do not use!
df_norm  = df
df_train = df_norm[:train_split-1]
df_valid = df_norm[train_split:]
df_train_labels = df[:train_split-1]  # unormalized!
df_valid_labels = df[train_split:]    # unormalized!

# Chop off ends so we have a full set of past elements and corresponding future
x_train = df_train.filter(like="A").values
y_train = df_train_labels.filter(items=["alpha"])[past+future-1:].values
x_valid = df_valid.filter(like="A").values
y_valid = df_valid_labels.filter(items=["alpha"])[past+future-1:].values
print("x_train shape: "+str(x_train.shape) + "   y_train shape: "+str(y_train.shape))
print("x_valid shape: "+str(x_valid.shape) + "   y_valid shape: "+str(y_valid.shape))
# Out:
# x_train shape: (2099, 51)   y_train shape: (1900, 1)
# x_valid shape: (900, 51)   y_valid shape: (701, 1)

# %% [markdown]
# ### Create Timeseries datasets
#
# This creates datasets in a form that can be easily used for training. Note that we use overlapping points. E.g. time steps 0-199 are used to predict $\alpha_{199}$, time steps 1-200 are used to predict $\alpha_{200}$, etc...
#
# The labels ("y"s defined in the cell above) start with the first predicted value. E.g. y_train[0] = $\alpha_{199}$, y_train[1] = $\alpha_{200}$, ...

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_train.take(1): train_inputs, train_targets = batch
print("  Training: Input shape:", train_inputs.numpy().shape, " Target shape:" , train_targets.numpy().shape)

dataset_valid = keras.preprocessing.timeseries_dataset_from_array(
    x_valid,
    y_valid,
    sequence_length=past,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in  dataset_valid.take(1): valid_inputs, valid_targets = batch
print("Validation: Input shape:", valid_inputs.numpy().shape, " Target shape:" , valid_targets.numpy().shape)
# Out:
#   Training: Input shape: (64, 200, 51)  Target shape: (64, 1)
# Validation: Input shape: (64, 200, 51)  Target shape: (64, 1)

# %% [markdown]
# ## Create Model 1
#
# This creates a simple model that uses just the estimated $\alpha$ and one Dense layer with 2 trainable parameters. It is fast and gives a pretty good result (<1% error). The layers and weights of this will be locked, but then used to create a second model later.

# %%
inputs = keras.layers.Input(shape=(train_inputs.shape[1], train_inputs.shape[2]))

# Estimated alpha for current time step
alpha_est_out = keras.layers.Lambda(lambda x: x[:, -1, -1])(inputs)
alpha_est_out = keras.layers.Reshape((1,))(alpha_est_out)
outputs       = keras.layers.Dense(1, activation="linear")(alpha_est_out)

model1 = keras.Model(inputs=inputs, outputs=outputs, name="model1")
model1.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model1.summary()
# Out:
# Model: "model1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 51)]         0
#
#  lambda (Lambda)             (None,)                   0
#
#  reshape (Reshape)           (None, 1)                 0
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Fit Model 1
#
# Use early stopping and save the best model to a _.h5_ file.

# %%
path_checkpoint = "model1_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=0,
    save_weights_only=True,
    save_best_only=True,
)

history1 = model1.fit(
    dataset_train,
    epochs=epochs_model1,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)

print("Cell completed at:", datetime.datetime.now())
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 10ms/step - loss: 0.1122 - val_loss: 0.0751
# Epoch 2/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0510 - val_loss: 0.0307
# Epoch 3/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0192 - val_loss: 0.0103
# Epoch 4/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0028
# Epoch 5/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 6.4770e-04
# Epoch 6/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 3.6944e-04 - val_loss: 1.5286e-04
# Epoch 7/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.4016e-04 - val_loss: 6.6054e-05
# Epoch 8/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0812e-04 - val_loss: 5.3964e-05
# Epoch 9/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0584e-04 - val_loss: 5.2458e-05
# Epoch 10/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0612e-04 - val_loss: 5.2241e-05
# Epoch 11/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0627e-04 - val_loss: 5.2194e-05
# Epoch 12/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0631e-04 - val_loss: 5.2173e-05
# Epoch 13/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0631e-04 - val_loss: 5.2153e-05
# Epoch 14/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0631e-04 - val_loss: 5.2132e-05
# Epoch 15/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0630e-04 - val_loss: 5.2110e-05
# Epoch 16/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0629e-04 - val_loss: 5.2088e-05
# Epoch 17/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0629e-04 - val_loss: 5.2065e-05
# Epoch 18/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0628e-04 - val_loss: 5.2041e-05
# Epoch 19/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0626e-04 - val_loss: 5.2018e-05
# Epoch 20/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0625e-04 - val_loss: 5.1992e-05
# Epoch 21/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0623e-04 - val_loss: 5.1967e-05
# Epoch 22/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0622e-04 - val_loss: 5.1941e-05
# Epoch 23/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0620e-04 - val_loss: 5.1914e-05
# Epoch 24/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0618e-04 - val_loss: 5.1887e-05
# Epoch 25/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0616e-04 - val_loss: 5.1859e-05
# Epoch 26/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0613e-04 - val_loss: 5.1831e-05
# Epoch 27/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0611e-04 - val_loss: 5.1802e-05
# Epoch 28/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0608e-04 - val_loss: 5.1772e-05
# Epoch 29/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0605e-04 - val_loss: 5.1741e-05
# Epoch 30/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0602e-04 - val_loss: 5.1710e-05
# Epoch 31/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0599e-04 - val_loss: 5.1679e-05
# Epoch 32/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0596e-04 - val_loss: 5.1647e-05
# Epoch 33/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0593e-04 - val_loss: 5.1614e-05
# Epoch 34/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0589e-04 - val_loss: 5.1580e-05
# Epoch 35/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0585e-04 - val_loss: 5.1546e-05
# Epoch 36/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0582e-04 - val_loss: 5.1512e-05
# Epoch 37/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0578e-04 - val_loss: 5.1476e-05
# Epoch 38/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0574e-04 - val_loss: 5.1440e-05
# Epoch 39/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0570e-04 - val_loss: 5.1404e-05
# Epoch 40/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0565e-04 - val_loss: 5.1367e-05
# Epoch 41/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0561e-04 - val_loss: 5.1329e-05
# Epoch 42/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0556e-04 - val_loss: 5.1291e-05
# Epoch 43/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0552e-04 - val_loss: 5.1252e-05
# Epoch 44/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0547e-04 - val_loss: 5.1212e-05
# Epoch 45/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0542e-04 - val_loss: 5.1172e-05
# Epoch 46/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0537e-04 - val_loss: 5.1132e-05
# Epoch 47/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0532e-04 - val_loss: 5.1090e-05
# Epoch 48/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0526e-04 - val_loss: 5.1049e-05
# Epoch 49/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0521e-04 - val_loss: 5.1006e-05
# Epoch 50/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0515e-04 - val_loss: 5.0962e-05
# Epoch 51/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0510e-04 - val_loss: 5.0919e-05
# Epoch 52/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0504e-04 - val_loss: 5.0875e-05
# Epoch 53/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0498e-04 - val_loss: 5.0830e-05
# Epoch 54/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0492e-04 - val_loss: 5.0784e-05
# Epoch 55/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0486e-04 - val_loss: 5.0738e-05
# Epoch 56/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0479e-04 - val_loss: 5.0691e-05
# Epoch 57/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0473e-04 - val_loss: 5.0644e-05
# Epoch 58/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0466e-04 - val_loss: 5.0596e-05
# Epoch 59/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0460e-04 - val_loss: 5.0547e-05
# Epoch 60/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0453e-04 - val_loss: 5.0498e-05
# Epoch 61/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0446e-04 - val_loss: 5.0448e-05
# Epoch 62/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0439e-04 - val_loss: 5.0398e-05
# Epoch 63/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0432e-04 - val_loss: 5.0347e-05
# Epoch 64/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0424e-04 - val_loss: 5.0296e-05
# Epoch 65/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0417e-04 - val_loss: 5.0244e-05
# Epoch 66/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0409e-04 - val_loss: 5.0192e-05
# Epoch 67/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0402e-04 - val_loss: 5.0138e-05
# Epoch 68/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0394e-04 - val_loss: 5.0085e-05
# Epoch 69/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0386e-04 - val_loss: 5.0030e-05
# Epoch 70/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0378e-04 - val_loss: 4.9976e-05
# Epoch 71/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0370e-04 - val_loss: 4.9921e-05
# Epoch 72/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0361e-04 - val_loss: 4.9865e-05
# Epoch 73/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0353e-04 - val_loss: 4.9808e-05
# Epoch 74/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0344e-04 - val_loss: 4.9751e-05
# Epoch 75/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0335e-04 - val_loss: 4.9694e-05
# Epoch 76/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0327e-04 - val_loss: 4.9636e-05
# Epoch 77/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0318e-04 - val_loss: 4.9577e-05
# Epoch 78/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0309e-04 - val_loss: 4.9518e-05
# Epoch 79/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0299e-04 - val_loss: 4.9459e-05
# Epoch 80/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0290e-04 - val_loss: 4.9399e-05
# Epoch 81/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0281e-04 - val_loss: 4.9338e-05
# Epoch 82/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0271e-04 - val_loss: 4.9278e-05
# Epoch 83/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0261e-04 - val_loss: 4.9216e-05
# Epoch 84/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0251e-04 - val_loss: 4.9154e-05
# Epoch 85/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0241e-04 - val_loss: 4.9092e-05
# Epoch 86/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0231e-04 - val_loss: 4.9029e-05
# Epoch 87/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0221e-04 - val_loss: 4.8966e-05
# Epoch 88/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0211e-04 - val_loss: 4.8902e-05
# Epoch 89/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0200e-04 - val_loss: 4.8838e-05
# Epoch 90/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0190e-04 - val_loss: 4.8774e-05
# Epoch 91/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0179e-04 - val_loss: 4.8709e-05
# Epoch 92/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0168e-04 - val_loss: 4.8644e-05
# Epoch 93/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0157e-04 - val_loss: 4.8578e-05
# Epoch 94/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0146e-04 - val_loss: 4.8512e-05
# Epoch 95/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0135e-04 - val_loss: 4.8446e-05
# Epoch 96/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0123e-04 - val_loss: 4.8379e-05
# Epoch 97/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0112e-04 - val_loss: 4.8312e-05
# Epoch 98/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0100e-04 - val_loss: 4.8244e-05
# Epoch 99/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0088e-04 - val_loss: 4.8177e-05
# Epoch 100/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0076e-04 - val_loss: 4.8108e-05
# Epoch 101/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0064e-04 - val_loss: 4.8040e-05
# Epoch 102/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0052e-04 - val_loss: 4.7971e-05
# Epoch 103/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0040e-04 - val_loss: 4.7902e-05
# Epoch 104/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0028e-04 - val_loss: 4.7833e-05
# Epoch 105/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0015e-04 - val_loss: 4.7763e-05
# Epoch 106/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0002e-04 - val_loss: 4.7693e-05
# Epoch 107/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9897e-05 - val_loss: 4.7623e-05
# Epoch 108/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9768e-05 - val_loss: 4.7553e-05
# Epoch 109/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9638e-05 - val_loss: 4.7482e-05
# Epoch 110/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9507e-05 - val_loss: 4.7411e-05
# Epoch 111/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9374e-05 - val_loss: 4.7340e-05
# Epoch 112/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9240e-05 - val_loss: 4.7269e-05
# Epoch 113/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9105e-05 - val_loss: 4.7197e-05
# Epoch 114/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.8969e-05 - val_loss: 4.7125e-05
# Epoch 115/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.8832e-05 - val_loss: 4.7053e-05
# Epoch 116/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.8693e-05 - val_loss: 4.6981e-05
# Epoch 117/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.8553e-05 - val_loss: 4.6909e-05
# Epoch 118/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 9.8413e-05 - val_loss: 4.6836e-05
# Epoch 119/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.8270e-05 - val_loss: 4.6763e-05
# Epoch 120/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.8127e-05 - val_loss: 4.6690e-05
# Epoch 121/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.7982e-05 - val_loss: 4.6617e-05
# Epoch 122/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.7836e-05 - val_loss: 4.6544e-05
# Epoch 123/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 9.7689e-05 - val_loss: 4.6470e-05
# Epoch 124/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.7542e-05 - val_loss: 4.6396e-05
# Epoch 125/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.7392e-05 - val_loss: 4.6323e-05
# Epoch 126/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.7242e-05 - val_loss: 4.6249e-05
# Epoch 127/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.7091e-05 - val_loss: 4.6175e-05
# Epoch 128/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6938e-05 - val_loss: 4.6100e-05
# Epoch 129/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6784e-05 - val_loss: 4.6026e-05
# Epoch 130/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6630e-05 - val_loss: 4.5951e-05
# Epoch 131/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6473e-05 - val_loss: 4.5876e-05
# Epoch 132/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6317e-05 - val_loss: 4.5802e-05
# Epoch 133/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6159e-05 - val_loss: 4.5727e-05
# Epoch 134/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.5999e-05 - val_loss: 4.5652e-05
# Epoch 135/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.5839e-05 - val_loss: 4.5576e-05
# Epoch 136/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.5678e-05 - val_loss: 4.5501e-05
# Epoch 137/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 9.5516e-05 - val_loss: 4.5425e-05
# Epoch 138/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.5352e-05 - val_loss: 4.5350e-05
# Epoch 139/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.5188e-05 - val_loss: 4.5274e-05
# Epoch 140/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.5022e-05 - val_loss: 4.5198e-05
# Epoch 141/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.4856e-05 - val_loss: 4.5122e-05
# Epoch 142/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.4689e-05 - val_loss: 4.5046e-05
# Epoch 143/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.4520e-05 - val_loss: 4.4970e-05
# Epoch 144/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.4351e-05 - val_loss: 4.4894e-05
# Epoch 145/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.4181e-05 - val_loss: 4.4818e-05
# Epoch 146/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.4011e-05 - val_loss: 4.4742e-05
# Epoch 147/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.3838e-05 - val_loss: 4.4665e-05
# Epoch 148/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.3665e-05 - val_loss: 4.4589e-05
# Epoch 149/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.3492e-05 - val_loss: 4.4513e-05
# Epoch 150/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.3317e-05 - val_loss: 4.4436e-05
# Epoch 151/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.3142e-05 - val_loss: 4.4360e-05
# Epoch 152/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.2965e-05 - val_loss: 4.4284e-05
# Epoch 153/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.2788e-05 - val_loss: 4.4208e-05
# Epoch 154/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.2611e-05 - val_loss: 4.4131e-05
# Epoch 155/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.2433e-05 - val_loss: 4.4055e-05
# Epoch 156/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.2253e-05 - val_loss: 4.3979e-05
# Epoch 157/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.2074e-05 - val_loss: 4.3904e-05
# Epoch 158/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.1893e-05 - val_loss: 4.3828e-05
# Epoch 159/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 9.1712e-05 - val_loss: 4.3752e-05
# Epoch 160/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.1530e-05 - val_loss: 4.3677e-05
# Epoch 161/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.1347e-05 - val_loss: 4.3602e-05
# Epoch 162/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.1164e-05 - val_loss: 4.3527e-05
# Epoch 163/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.0981e-05 - val_loss: 4.3453e-05
# Epoch 164/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.0797e-05 - val_loss: 4.3378e-05
# Epoch 165/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.0612e-05 - val_loss: 4.3304e-05
# Epoch 166/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.0427e-05 - val_loss: 4.3230e-05
# Epoch 167/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 9.0242e-05 - val_loss: 4.3157e-05
# Epoch 168/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 9.0056e-05 - val_loss: 4.3084e-05
# Epoch 169/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.9870e-05 - val_loss: 4.3011e-05
# Epoch 170/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.9683e-05 - val_loss: 4.2939e-05
# Epoch 171/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.9495e-05 - val_loss: 4.2867e-05
# Epoch 172/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.9309e-05 - val_loss: 4.2796e-05
# Epoch 173/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 8.9121e-05 - val_loss: 4.2725e-05
# Epoch 174/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.8933e-05 - val_loss: 4.2654e-05
# Epoch 175/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 8.8745e-05 - val_loss: 4.2584e-05
# Epoch 176/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.8557e-05 - val_loss: 4.2515e-05
# Epoch 177/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 8.8369e-05 - val_loss: 4.2446e-05
# Epoch 178/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.8180e-05 - val_loss: 4.2378e-05
# Epoch 179/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.7991e-05 - val_loss: 4.2310e-05
# Epoch 180/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.7803e-05 - val_loss: 4.2243e-05
# Epoch 181/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 8.7614e-05 - val_loss: 4.2176e-05
# Epoch 182/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.7426e-05 - val_loss: 4.2110e-05
# Epoch 183/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.7237e-05 - val_loss: 4.2045e-05
# Epoch 184/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.7049e-05 - val_loss: 4.1981e-05
# Epoch 185/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.6861e-05 - val_loss: 4.1917e-05
# Epoch 186/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.6673e-05 - val_loss: 4.1853e-05
# Epoch 187/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.6484e-05 - val_loss: 4.1791e-05
# Epoch 188/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.6296e-05 - val_loss: 4.1729e-05
# Epoch 189/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.6108e-05 - val_loss: 4.1668e-05
# Epoch 190/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.5921e-05 - val_loss: 4.1607e-05
# Epoch 191/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.5734e-05 - val_loss: 4.1548e-05
# Epoch 192/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.5546e-05 - val_loss: 4.1489e-05
# Epoch 193/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 8.5360e-05 - val_loss: 4.1430e-05
# Epoch 194/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.5173e-05 - val_loss: 4.1373e-05
# Epoch 195/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.4988e-05 - val_loss: 4.1316e-05
# Epoch 196/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.4802e-05 - val_loss: 4.1260e-05
# Epoch 197/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.4616e-05 - val_loss: 4.1205e-05
# Epoch 198/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.4432e-05 - val_loss: 4.1151e-05
# Epoch 199/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.4247e-05 - val_loss: 4.1098e-05
# Epoch 200/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.4064e-05 - val_loss: 4.1045e-05
# Epoch 201/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.3881e-05 - val_loss: 4.0993e-05
# Epoch 202/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.3698e-05 - val_loss: 4.0941e-05
# Epoch 203/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.3515e-05 - val_loss: 4.0891e-05
# Epoch 204/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.3334e-05 - val_loss: 4.0841e-05
# Epoch 205/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.3153e-05 - val_loss: 4.0792e-05
# Epoch 206/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.2972e-05 - val_loss: 4.0744e-05
# Epoch 207/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.2792e-05 - val_loss: 4.0697e-05
# Epoch 208/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 8.2612e-05 - val_loss: 4.0651e-05
# Epoch 209/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.2434e-05 - val_loss: 4.0605e-05
# Epoch 210/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.2256e-05 - val_loss: 4.0560e-05
# Epoch 211/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 8.2079e-05 - val_loss: 4.0517e-05
# Epoch 212/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1903e-05 - val_loss: 4.0473e-05
# Epoch 213/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1727e-05 - val_loss: 4.0431e-05
# Epoch 214/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1552e-05 - val_loss: 4.0389e-05
# Epoch 215/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1377e-05 - val_loss: 4.0348e-05
# Epoch 216/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1204e-05 - val_loss: 4.0309e-05
# Epoch 217/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1031e-05 - val_loss: 4.0269e-05
# Epoch 218/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0859e-05 - val_loss: 4.0231e-05
# Epoch 219/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0688e-05 - val_loss: 4.0193e-05
# Epoch 220/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0518e-05 - val_loss: 4.0156e-05
# Epoch 221/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0348e-05 - val_loss: 4.0120e-05
# Epoch 222/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0179e-05 - val_loss: 4.0085e-05
# Epoch 223/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0012e-05 - val_loss: 4.0051e-05
# Epoch 224/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9844e-05 - val_loss: 4.0017e-05
# Epoch 225/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9678e-05 - val_loss: 3.9984e-05
# Epoch 226/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9513e-05 - val_loss: 3.9951e-05
# Epoch 227/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9348e-05 - val_loss: 3.9920e-05
# Epoch 228/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9185e-05 - val_loss: 3.9889e-05
# Epoch 229/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9023e-05 - val_loss: 3.9859e-05
# Epoch 230/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.8861e-05 - val_loss: 3.9830e-05
# Epoch 231/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.8700e-05 - val_loss: 3.9802e-05
# Epoch 232/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.8541e-05 - val_loss: 3.9774e-05
# Epoch 233/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.8381e-05 - val_loss: 3.9747e-05
# Epoch 234/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.8223e-05 - val_loss: 3.9721e-05
# Epoch 235/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.8066e-05 - val_loss: 3.9695e-05
# Epoch 236/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.7910e-05 - val_loss: 3.9670e-05
# Epoch 237/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.7755e-05 - val_loss: 3.9646e-05
# Epoch 238/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.7601e-05 - val_loss: 3.9623e-05
# Epoch 239/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.7448e-05 - val_loss: 3.9600e-05
# Epoch 240/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.7295e-05 - val_loss: 3.9578e-05
# Epoch 241/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.7144e-05 - val_loss: 3.9557e-05
# Epoch 242/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.6994e-05 - val_loss: 3.9536e-05
# Epoch 243/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.6845e-05 - val_loss: 3.9517e-05
# Epoch 244/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.6696e-05 - val_loss: 3.9497e-05
# Epoch 245/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.6549e-05 - val_loss: 3.9479e-05
# Epoch 246/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.6402e-05 - val_loss: 3.9461e-05
# Epoch 247/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.6257e-05 - val_loss: 3.9444e-05
# Epoch 248/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.6112e-05 - val_loss: 3.9427e-05
# Epoch 249/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5968e-05 - val_loss: 3.9411e-05
# Epoch 250/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5826e-05 - val_loss: 3.9396e-05
# Epoch 251/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5685e-05 - val_loss: 3.9381e-05
# Epoch 252/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5544e-05 - val_loss: 3.9367e-05
# Epoch 253/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.5405e-05 - val_loss: 3.9354e-05
# Epoch 254/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5266e-05 - val_loss: 3.9341e-05
# Epoch 255/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5128e-05 - val_loss: 3.9329e-05
# Epoch 256/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4991e-05 - val_loss: 3.9317e-05
# Epoch 257/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4856e-05 - val_loss: 3.9307e-05
# Epoch 258/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4722e-05 - val_loss: 3.9296e-05
# Epoch 259/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4588e-05 - val_loss: 3.9286e-05
# Epoch 260/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4454e-05 - val_loss: 3.9277e-05
# Epoch 261/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4323e-05 - val_loss: 3.9269e-05
# Epoch 262/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.4192e-05 - val_loss: 3.9261e-05
# Epoch 263/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.4062e-05 - val_loss: 3.9254e-05
# Epoch 264/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.3933e-05 - val_loss: 3.9247e-05
# Epoch 265/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.3806e-05 - val_loss: 3.9240e-05
# Epoch 266/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.3679e-05 - val_loss: 3.9235e-05
# Epoch 267/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.3553e-05 - val_loss: 3.9230e-05
# Epoch 268/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.3428e-05 - val_loss: 3.9225e-05
# Epoch 269/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.3303e-05 - val_loss: 3.9221e-05
# Epoch 270/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.3181e-05 - val_loss: 3.9217e-05
# Epoch 271/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.3058e-05 - val_loss: 3.9214e-05
# Epoch 272/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2937e-05 - val_loss: 3.9212e-05
# Epoch 273/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2817e-05 - val_loss: 3.9210e-05
# Epoch 274/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2697e-05 - val_loss: 3.9209e-05
# Epoch 275/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2579e-05 - val_loss: 3.9208e-05
# Epoch 276/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2462e-05 - val_loss: 3.9207e-05
# Epoch 277/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2345e-05 - val_loss: 3.9208e-05
# Epoch 278/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.2229e-05 - val_loss: 3.9208e-05
# Epoch 279/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.2114e-05 - val_loss: 3.9209e-05
# Epoch 280/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2001e-05 - val_loss: 3.9211e-05
# Epoch 281/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1888e-05 - val_loss: 3.9213e-05
# Epoch 282/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1776e-05 - val_loss: 3.9215e-05
# Epoch 283/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.1665e-05 - val_loss: 3.9218e-05
# Epoch 284/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1555e-05 - val_loss: 3.9222e-05
# Epoch 285/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1446e-05 - val_loss: 3.9225e-05
# Epoch 286/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1337e-05 - val_loss: 3.9230e-05
# Epoch 287/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1230e-05 - val_loss: 3.9234e-05
# Epoch 288/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1123e-05 - val_loss: 3.9240e-05
# Epoch 289/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1018e-05 - val_loss: 3.9245e-05
# Epoch 290/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.0913e-05 - val_loss: 3.9251e-05
# Epoch 291/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.0809e-05 - val_loss: 3.9258e-05
# Epoch 292/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.0706e-05 - val_loss: 3.9265e-05
# Epoch 293/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.0604e-05 - val_loss: 3.9272e-05
# Epoch 294/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.0502e-05 - val_loss: 3.9280e-05
# Epoch 295/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.0402e-05 - val_loss: 3.9288e-05
# Epoch 296/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.0302e-05 - val_loss: 3.9296e-05
# Epoch 297/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 7.0203e-05 - val_loss: 3.9305e-05
# Epoch 298/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.0106e-05 - val_loss: 3.9315e-05
# Epoch 299/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.0008e-05 - val_loss: 3.9324e-05
# Epoch 300/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9912e-05 - val_loss: 3.9334e-05
# Epoch 301/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 6.9816e-05 - val_loss: 3.9345e-05
# Epoch 302/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9722e-05 - val_loss: 3.9356e-05
# Epoch 303/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9628e-05 - val_loss: 3.9367e-05
# Epoch 304/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9535e-05 - val_loss: 3.9378e-05
# Epoch 305/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9443e-05 - val_loss: 3.9390e-05
# Epoch 306/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9351e-05 - val_loss: 3.9403e-05
# Epoch 307/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9261e-05 - val_loss: 3.9415e-05
# Epoch 308/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9171e-05 - val_loss: 3.9428e-05
# Epoch 309/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.9082e-05 - val_loss: 3.9441e-05
# Epoch 310/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8994e-05 - val_loss: 3.9455e-05
# Epoch 311/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8906e-05 - val_loss: 3.9469e-05
# Epoch 312/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8820e-05 - val_loss: 3.9483e-05
# Epoch 313/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 6.8733e-05 - val_loss: 3.9497e-05
# Epoch 314/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8648e-05 - val_loss: 3.9512e-05
# Epoch 315/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8564e-05 - val_loss: 3.9527e-05
# Epoch 316/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8480e-05 - val_loss: 3.9543e-05
# Epoch 317/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 6.8398e-05 - val_loss: 3.9559e-05
# Epoch 318/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8315e-05 - val_loss: 3.9575e-05
# Epoch 319/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8234e-05 - val_loss: 3.9591e-05
# Epoch 320/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.8153e-05 - val_loss: 3.9608e-05
# Epoch 321/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 6.8073e-05 - val_loss: 3.9625e-05
# Epoch 322/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.7994e-05 - val_loss: 3.9642e-05
# Epoch 323/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 6.7915e-05 - val_loss: 3.9659e-05
# Epoch 324/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 6.7837e-05 - val_loss: 3.9677e-05
# Epoch 325/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.7760e-05 - val_loss: 3.9695e-05
# Epoch 326/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.7683e-05 - val_loss: 3.9713e-05
# Cell completed at: 2023-08-28 08:11:51.145318

# %% [markdown]
# ### Loss Function Model 1
#
# n.b. This is plotted on a log scale

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.yscale("log")
    plt.legend()
    plt.show()


visualize_loss(history1, "Training and Validation Loss")

# %% [markdown]
# ## Results Model 1
#
# The following cell performs inference on the entire dataset (training and validation). The results are stored in the original dataframe as column "alpha_model1".

# %%
# Create overlapping windows of data
x_all = df_norm.filter(like="A").values
num_windows = x_all.shape[0] - past +1
windows = np.lib.stride_tricks.sliding_window_view(x_all, (past, x_all.shape[1]))

df['alpha_model1'] = np.nan

# Predict using batches and update df
batch_size_ = 32
for i in range(0, num_windows, batch_size_):
    batch_windows = windows[i:i+batch_size_]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model1.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model1'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")

print("\rprocessed: {}/{}".format(num_windows, num_windows), end="")
# Out:
# processed: 2801/2801

# %% [markdown]
# # $\alpha$ Model 1 vs Truth
#
# The top plot below shows the true $\alpha$ and the one predicted by model 1. Since the model requires 200 past timesteps, its predictions are only available for timestep 200 and later.
#
# The bottom plot shows the error (residual) bewtween $\alpha$ and the model 1 prediction.

# %%
df.plot(y=["alpha_model1", "alpha"], kind="line", grid=True, figsize=(10,3))

df["alpha_res1"] = df["alpha_model1"] - df["alpha"]
df.plot(y=["alpha_res1"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# ## Create Model 2
#
# This creates an LSTM model that uses just the model 1 output of a corrected estimated $\alpha$ as input. The LSTM model is then trained to correct the residual. The layers of model 1 are reused here, but the two trainable parameters are locked so as not no be updated by this model's training, forcing the additional layers of this model to fit to the residual.

# %%
# Lock the parameters in model 1
outputs.trainable = False

# Residual for corrected alpha
lstm_out = keras.layers.LSTM(200, activation="tanh", recurrent_activation="tanh", kernel_initializer='zeros')(inputs)
residual_out = keras.layers.Dense(1, activation="tanh", kernel_initializer='zeros')(lstm_out)

# The residual should be a small number relative to 1. Scale the value down here to put it in a reasonable range
residual_out = keras.layers.Lambda(lambda x: x * 0.10)(residual_out)

# Add model 1 and residual to make outputs for model 2
outputs2 = keras.layers.Add()([outputs, residual_out])


model2 = keras.Model(inputs=inputs, outputs=outputs2, name="model2")
model2.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model2.summary()

import datetime
# Out:
# Model: "model2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 51)]            0         []
#
#  lambda (Lambda)             (None,)                      0         ['input_1[0][0]']
#
#  lstm (LSTM)                 (None, 200)                  201600    ['input_1[0][0]']
#
#  reshape (Reshape)           (None, 1)                    0         ['lambda[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    201       ['lstm[0][0]']
#
#  dense (Dense)               (None, 1)                    2         ['reshape[0][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['dense_1[0][0]']
#
#  add (Add)                   (None, 1)                    0         ['dense[0][0]',
#                                                                      'lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 201803 (788.29 KB)
# Trainable params: 201803 (788.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Fit Model 2
#
# Use early stopping and save the best model to a _.h5_ file.

# %%
path_checkpoint = "model2_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history2 = model2.fit(
    dataset_train,
    epochs=epochs_model1,
    validation_data=dataset_valid,
    callbacks=[es_callback, modelckpt_callback],
)

print("Cell completed at:", datetime.datetime.now())
# Out:
# Epoch 1/5000
# 30/30 [==============================] - ETA: 0s - loss: 8.9328e-05
# Epoch 1: val_loss improved from inf to 0.00004, saving model to model2_checkpoint.h5
# 30/30 [==============================] - 12s 360ms/step - loss: 8.9328e-05 - val_loss: 4.2626e-05
# Epoch 2/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5560e-05
# Epoch 2: val_loss improved from 0.00004 to 0.00004, saving model to model2_checkpoint.h5
# 30/30 [==============================] - 11s 354ms/step - loss: 6.5560e-05 - val_loss: 3.9698e-05
# Epoch 3/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7092e-05
# Epoch 3: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 359ms/step - loss: 6.7092e-05 - val_loss: 3.9752e-05
# Epoch 4/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7641e-05
# Epoch 4: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 366ms/step - loss: 6.7641e-05 - val_loss: 3.9773e-05
# Epoch 5/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7735e-05
# Epoch 5: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 357ms/step - loss: 6.7735e-05 - val_loss: 3.9790e-05
# Epoch 6/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7722e-05
# Epoch 6: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 364ms/step - loss: 6.7722e-05 - val_loss: 3.9809e-05
# Epoch 7/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7685e-05
# Epoch 7: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.7685e-05 - val_loss: 3.9831e-05
# Epoch 8/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7638e-05
# Epoch 8: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.7638e-05 - val_loss: 3.9852e-05
# Epoch 9/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7586e-05
# Epoch 9: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.7586e-05 - val_loss: 3.9874e-05
# Epoch 10/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7528e-05
# Epoch 10: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 363ms/step - loss: 6.7528e-05 - val_loss: 3.9896e-05
# Epoch 11/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7467e-05
# Epoch 11: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 361ms/step - loss: 6.7467e-05 - val_loss: 3.9918e-05
# Epoch 12/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7404e-05
# Epoch 12: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 353ms/step - loss: 6.7404e-05 - val_loss: 3.9941e-05
# Epoch 13/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7340e-05
# Epoch 13: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.7340e-05 - val_loss: 3.9964e-05
# Epoch 14/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7274e-05
# Epoch 14: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 362ms/step - loss: 6.7274e-05 - val_loss: 3.9987e-05
# Epoch 15/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7208e-05
# Epoch 15: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.7208e-05 - val_loss: 4.0010e-05
# Epoch 16/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7141e-05
# Epoch 16: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 349ms/step - loss: 6.7141e-05 - val_loss: 4.0033e-05
# Epoch 17/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7075e-05
# Epoch 17: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 343ms/step - loss: 6.7075e-05 - val_loss: 4.0057e-05
# Epoch 18/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.7008e-05
# Epoch 18: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 352ms/step - loss: 6.7008e-05 - val_loss: 4.0080e-05
# Epoch 19/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6941e-05
# Epoch 19: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.6941e-05 - val_loss: 4.0104e-05
# Epoch 20/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6874e-05
# Epoch 20: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 350ms/step - loss: 6.6874e-05 - val_loss: 4.0128e-05
# Epoch 21/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6808e-05
# Epoch 21: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 360ms/step - loss: 6.6808e-05 - val_loss: 4.0153e-05
# Epoch 22/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6742e-05
# Epoch 22: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.6742e-05 - val_loss: 4.0177e-05
# Epoch 23/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6677e-05
# Epoch 23: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 349ms/step - loss: 6.6677e-05 - val_loss: 4.0202e-05
# Epoch 24/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6611e-05
# Epoch 24: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.6611e-05 - val_loss: 4.0227e-05
# Epoch 25/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6547e-05
# Epoch 25: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 354ms/step - loss: 6.6547e-05 - val_loss: 4.0252e-05
# Epoch 26/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6483e-05
# Epoch 26: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 357ms/step - loss: 6.6483e-05 - val_loss: 4.0277e-05
# Epoch 27/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6419e-05
# Epoch 27: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 359ms/step - loss: 6.6419e-05 - val_loss: 4.0303e-05
# Epoch 28/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6356e-05
# Epoch 28: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 348ms/step - loss: 6.6356e-05 - val_loss: 4.0328e-05
# Epoch 29/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6293e-05
# Epoch 29: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 355ms/step - loss: 6.6293e-05 - val_loss: 4.0354e-05
# Epoch 30/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6231e-05
# Epoch 30: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.6231e-05 - val_loss: 4.0380e-05
# Epoch 31/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6170e-05
# Epoch 31: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 346ms/step - loss: 6.6170e-05 - val_loss: 4.0406e-05
# Epoch 32/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6109e-05
# Epoch 32: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 349ms/step - loss: 6.6109e-05 - val_loss: 4.0432e-05
# Epoch 33/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.6048e-05
# Epoch 33: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 358ms/step - loss: 6.6048e-05 - val_loss: 4.0458e-05
# Epoch 34/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5989e-05
# Epoch 34: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 353ms/step - loss: 6.5989e-05 - val_loss: 4.0485e-05
# Epoch 35/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5929e-05
# Epoch 35: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.5929e-05 - val_loss: 4.0512e-05
# Epoch 36/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5871e-05
# Epoch 36: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 348ms/step - loss: 6.5871e-05 - val_loss: 4.0539e-05
# Epoch 37/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5812e-05
# Epoch 37: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.5812e-05 - val_loss: 4.0565e-05
# Epoch 38/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5755e-05
# Epoch 38: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 350ms/step - loss: 6.5755e-05 - val_loss: 4.0593e-05
# Epoch 39/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5698e-05
# Epoch 39: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 358ms/step - loss: 6.5698e-05 - val_loss: 4.0620e-05
# Epoch 40/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5641e-05
# Epoch 40: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 344ms/step - loss: 6.5641e-05 - val_loss: 4.0647e-05
# Epoch 41/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5585e-05
# Epoch 41: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 360ms/step - loss: 6.5585e-05 - val_loss: 4.0674e-05
# Epoch 42/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5530e-05
# Epoch 42: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.5530e-05 - val_loss: 4.0702e-05
# Epoch 43/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5475e-05
# Epoch 43: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 351ms/step - loss: 6.5475e-05 - val_loss: 4.0730e-05
# Epoch 44/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5421e-05
# Epoch 44: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 357ms/step - loss: 6.5421e-05 - val_loss: 4.0757e-05
# Epoch 45/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5368e-05
# Epoch 45: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 355ms/step - loss: 6.5368e-05 - val_loss: 4.0785e-05
# Epoch 46/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5314e-05
# Epoch 46: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 358ms/step - loss: 6.5314e-05 - val_loss: 4.0813e-05
# Epoch 47/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5262e-05
# Epoch 47: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 361ms/step - loss: 6.5262e-05 - val_loss: 4.0841e-05
# Epoch 48/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5210e-05
# Epoch 48: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 354ms/step - loss: 6.5210e-05 - val_loss: 4.0869e-05
# Epoch 49/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5159e-05
# Epoch 49: val_loss did not improve from 0.00004
# 30/30 [==============================] - 11s 356ms/step - loss: 6.5159e-05 - val_loss: 4.0897e-05
# Epoch 50/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5107e-05
# Epoch 50: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.5107e-05 - val_loss: 4.0926e-05
# Epoch 51/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5057e-05
# Epoch 51: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 347ms/step - loss: 6.5057e-05 - val_loss: 4.0954e-05
# Epoch 52/5000
# 30/30 [==============================] - ETA: 0s - loss: 6.5007e-05
# Epoch 52: val_loss did not improve from 0.00004
# 30/30 [==============================] - 10s 350ms/step - loss: 6.5007e-05 - val_loss: 4.0983e-05
# Cell completed at: 2023-08-28 08:21:10.567425

# %% [markdown]
# ### Loss Function Model 2
#
# n.b. This is plotted on a log scale

# %%
visualize_loss(history2, "Training and Validation Loss")

# %% [markdown]
# ## Results Model 2
#
# The following cell performs inference on the entire dataset (training and validation). The results are stored in the original dataframe as column "alpha_model2".

# %%
df['alpha_model2'] = np.nan

# Predict using batches and update df
batch_size_ = 32
for i in range(0, num_windows, batch_size_):
    batch_windows = windows[i:i+batch_size_]
     # Reshape batch_windows to match the model's input shape
    batch_windows_reshaped = np.reshape(batch_windows, (batch_windows.shape[0], past, batch_windows.shape[-1]))
    y_pred_batch = model2.predict(batch_windows_reshaped, verbose=0)
    y_pred_batch_flattened = y_pred_batch.flatten()
    this_batch_size = batch_windows.shape[0]
    df.loc[i+past-1:i+this_batch_size+past-1-1, 'alpha_model2'] = y_pred_batch
    print("\rprocessed: {}/{}".format(i, num_windows), end="")

print("\rprocessed: {}/{}".format(num_windows, num_windows), end="")
# Out:
# processed: 2801/2801

# %% [markdown]
# # $\alpha$ Model 2 vs Truth
#
# The top plot below shows the true $\alpha$ and the one predicted by model 2. Since the model requires 200 past timesteps, its predictions are only available for timestep 200 and later.
#
# The bottom plot shows the error (residual) bewtween $\alpha$ and the model 2 prediction.

# %%
df.plot(y=["alpha_model1", "alpha", "alpha_model2"], kind="line", grid=True, figsize=(10,3))

df["alpha_res2"] = df["alpha_model2"] - df["alpha"]
df.plot(y=["alpha_res1", "alpha_res2"], kind="line", grid=True, figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# # Basement
# <hr>

# %% [markdown]
# ### Example predictions
#
# Plot a few examples showing the $\alpha$ truth history and the model prediction. This is also carried over from the keras weather example. The red "X" is just the last point in the truth history since here, we are not trying to predict the future, only use the past to predict the present.
#
# n.b. Unlike the original example for the weather which included Temperature in the features and was used to predict Temperature in the future, this problem does not directly measure $\alpha$. Thus these blue points are useful to guide the human eye, but are not values the model sees.
#
# The first 3 plots are from the validation set while the second three are from the training set.

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future_ = delta
    else:
        future_ = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future_, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend(loc="upper left")
    plt.xlim([time_steps[0], (future_ + 5) * 2])
    plt.ylim([0.90, 1.10])
    plt.xlabel("Time-Step")
    plt.show()
    return

# This has the alpha history with last point being the same as the label
alpha_valid = df_valid_labels.filter(items=["alpha"])[:-(past+future)].values
alpha_train = df_train_labels.filter(items=["alpha"])[:-(past+future)].values

 
# Validation examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_valid[start:start+past], 0)
    y_history = alpha_valid[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model2.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from Validation Set")

# Training examples
for i in range(3):
    start = i*62
    x = np.expand_dims(x_train[start:start+past], 0)
    y_history = alpha_train[start:start+past-1]
    y_true = y_history[-1]
    # print("shape x: ", x.shape, '  y_history:',y_history.shape, ' y_true:',y_true.shape)
    y_pred = model2.predict(x)
    # print('shape y_pred:',y_pred.shape)
    show_plot(  [y_history, y_true, y_pred], 0, "Example from training Set")
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
